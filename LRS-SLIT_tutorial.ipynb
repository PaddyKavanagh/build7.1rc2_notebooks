# %% [markdown]
# # LRS-SLIT pipeline tutorial

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) August 28th 2017

# %% [markdown]
# This notebook demonstrates the execution of the level 2A and 2B pipelines for LRS-SLIT data in Python using the jwst step classes.
#
# Documentation on each pipeline step can be found here:
#
# http://ssb.stsci.edu/doc/jwst_dev/
#
# The pipeline steps are:
#
# 2A: dq_init, saturation, linearity, RSCD, lastframe, dark_current, refpix, jump, ramp_fitting
#
# 2B: assign_wcs, bkg_subtract, flat_field, srctype, photom, extract_1d
#
# The files used in this notebook is an undithered MIRISim simulation of a point source with a blackbody spectrum plus emission lines. A dedicated background observation is also used for subtraction at the level 2 stage. We will run through the steps of the SloperPipeline on the on-source observation only. We will process the background observation using the full pipeline for use in the Spec2Pipeline
#
# In this notebook we will pass the step output to subsequent step input in datamodel form. The output from each step is also writting to a fits file.

# %% [markdown]
# #### imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from copy import deepcopy

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file, output directory for step outputs:

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'LRS-SLIT_demo_data'
input_dir = 'LRS-SLIT_demo_data'
input_file = glob.glob(os.path.join(input_dir,'det*.fits'))[0]

# load the background observation
bkg_file = glob.glob(os.path.join(input_dir,'bkg*.fits'))[0]

# set the output directory name
output_dir = input_dir + '_step_output'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input file.
# Note that ground test data and MIRISim data will differ here. We can distinguish between the two using the 'ORIGIN' header keyword. Converted ground test data will always have 'STScI' as the origin.
#
# Also note that there is currently a problem running MIRISim data step-wise through the pipeline. One must remove some of the extensions. This has been taken care of in the following cell. This issue has been reported to STScI and this notebook will be updated when it is resolved.

# %%
# print some info on input file
with fits.open(input_file) as hdulist:
        
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t\t\t Detector\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "%s\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (identifier,detector,im_filter,subArr,nInts,nGroups,readPatt,expTime)
        print "\n\n"
            
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['EXP_TYPE']
        im_filter = hdulist[0].header['FILTER']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        print "ID\t Type\t\t\t Filter\t subAr\t nInts\t nGrps\t rdPatt\t ExpTime (s)"
        print "--------------------------------------------------------------------------------------------------"
        print "MIRISim\t %s\t %s\t %s\t %d\t %d\t %s\t %0.1f" % (detector,im_filter,subArr, nInts,nGroups,readPatt,expTime)
        print "\n\n"

    # fits extension table
    hdulist.info()
# Out:
# ID	 Type			 Filter	 subAr	 nInts	 nGrps	 rdPatt	 ExpTime (s)
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIR_LRS-FIXEDSLIT	 P750L	 FULL	 2	 50	 FAST	 277.5
#
#
#
# Filename: LRS-SLIT_demo_data/det_image_1_MIRIMAGE_P750Lexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     147   ()
#   1  SCI           1 ImageHDU        14   (1032, 1024, 50, 2)   float32
#   2  REFOUT        1 ImageHDU        14   (258, 1024, 50, 2)   float32
#   3  PIXELDQ       1 ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF    1 BinTableHDU     17   29R x 4C   [J, J, 40A, 128A]
#   5  ASDF          1 ImageHDU         7   (533679032,)   uint8

# %% [markdown]
# ## DQ_INIT step ===================================================
# This step creates the PIXELDQ, GROUPDQ and ERR extensions in the ramp file
# which are copied from the calibration file. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/dq_init/index.html

# %% [markdown]
# ### DQ_INIT: load module and show options

# %%
# import the step
from jwst.dq_init import dq_init_step

# print the description and options
print dq_init_step.DQInitStep.__doc__
print dq_init_step.DQInitStep.spec
# Out:
#     DQInitStep:  Initialize the Data Quality extension from the
#     mask reference file.  Also initialize the error extension
#
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# ### DQ_INIT: run step

# %%
# run the dq_init step
dm = dq_init_step.DQInitStep.call(input_file, save_results=True, output_dir=output_dir, output_file='dq_init_out.fits')
# Out:
# 2017-08-31 13:32:58,285 - stpipe.DQInitStep - INFO - DQInitStep instance created.
# 2017-08-31 13:33:01,871 - stpipe.DQInitStep - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2017-08-31 13:33:01,923 - stpipe.DQInitStep - INFO - Step DQInitStep running with args ('LRS-SLIT_demo_data/det_image_1_MIRIMAGE_P750Lexp1.fits',).
# 2017-08-31 13:33:03,611 - stpipe.DQInitStep - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2017-08-31 13:33:13,454 - stpipe.DQInitStep - INFO - Saving file LRS-SLIT_demo_data_step_output/dq_init_out.fits
# 2017-08-31 13:33:15,198 - stpipe.DQInitStep - INFO - Step DQInitStep done

# %% [markdown]
# ### DQ_INIT:  output check
#
# 1. check the output datamodel to show values in the new extensions, check that some pixels have been assigned new flags from the mask file

# %%
# check the calibration step information
print'Check dq_init step information status:'
print dm.meta.cal_step.dq_init

# print unique values in the PIXELDQ extension
print "\nDQ flags values in PIXELDQ:"
print ', '.join(map(str, np.unique(dm.pixeldq)))

# print unique values in the GROUPDQ extension
print "\nDQ flags values in GROUPDQ extension:"
print ', '.join(map(str, np.unique(dm.groupdq)))
# Out:
# Check dq_init step information status:
# COMPLETE
#
# DQ flags values in PIXELDQ:
# 0, 512, 1025, 2049, 16385, 16777216, 16777217, 16777729
#
# DQ flags values in GROUPDQ extension:
# 0

# %% [markdown]
# ### DQ_INIT:  output plots
#
# 1. plot the science data
#
# 2. plot the PIXEL_DQ extension to show which pixels have been flagged

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# show last frame of first integration
axs[0].imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
axs[0].annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

# plot the PIXEL_DQ frame
axs[1].imshow(dm.pixeldq, cmap='gray', interpolation='nearest', origin='lower', vmin=0, vmax=1)
axs[1].annotate('PIXELDQ', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## SATURATION step ============================================
# The saturation step flags saturated pixel for each integration by reading the calibration reference
# file that specifies the saturation level for each pixel. The saturation flags are set in the fram of the GROUPDQ extension where the pixel reaches saturation. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/saturation/index.html

# %% [markdown]
# ### SATURATION: load module and show options

# %%
# import the step
from jwst.saturation import saturation_step

# print the description and options
print saturation_step.SaturationStep.__doc__
print saturation_step.SaturationStep.spec
# Out:
#     This Step sets saturation flags.
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# ### SATURATION: run step

# %%
# run the saturation step
dm = saturation_step.SaturationStep.call(dm, save_results=True, output_dir=output_dir, output_file='saturation_out.fits')
# Out:
# 2017-08-31 13:33:17,429 - stpipe.SaturationStep - INFO - SaturationStep instance created.
# 2017-08-31 13:33:18,131 - stpipe.SaturationStep - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2017-08-31 13:33:18,198 - stpipe.SaturationStep - INFO - Step SaturationStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1185bb490>,).
# 2017-08-31 13:33:18,654 - stpipe.SaturationStep - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2017-08-31 13:33:20,263 - stpipe.SaturationStep - INFO - Saving file LRS-SLIT_demo_data_step_output/saturation_out.fits
# 2017-08-31 13:33:22,605 - stpipe.SaturationStep - INFO - Step SaturationStep done

# %% [markdown]
# ### SATURATION:  output check
#
# 1. saturated pixels will be flagged in the GROUPDQ extension with the number 2. Check that some pixels in this extension are now flagged as saturated

# %%
# check the calibration step information
print'Check saturation step information status:'
print dm.meta.cal_step.saturation

# print unique values in the GROUPDQ extension
print "\nDQ flags values in GROUPDQ extension:"
print ', '.join(map(str, np.unique(dm.groupdq)))
# Out:
# Check saturation step information status:
# COMPLETE
#
# DQ flags values in GROUPDQ extension:
# 0, 2

# %% [markdown]
# ### SATURATION:  output plots
#
# 1. plot the science data
#
# 2. plot the GROUP_DQ extension to show which pixels have been flagged as saturated

# %%
# plot--------------------------------------   
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# show last frame of first integration
axs[0].imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
axs[0].annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

# plot last frame of first integration GROUP_DQ
axs[1].imshow(np.sum(dm.groupdq[0],axis=0), cmap='gray', interpolation='nearest', origin='lower', vmin=0, vmax=1)
axs[1].annotate('GRUOPDQ', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## LINEARITY step ===============================================
#
# This step corrects for detector non-linearity. The linearity coefficients are read from the linearity correction reference file.
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/linearity/index.html

# %% [markdown]
# ### LINEARITY: load module and show options

# %%
# import the step
from jwst.linearity import linearity_step

# print the description and options
print linearity_step.LinearityStep.__doc__
print linearity_step.LinearityStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     LinearityStep: This step performs a correction for non-linear
#     detector response, using the "classic" polynomial method.
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# ### LINEARITY: run step

# %%
# run the linearity step
dm = linearity_step.LinearityStep.call(dm, save_results=True, output_dir=output_dir, output_file='linearity_out.fits')
# Out:
# 2017-08-31 13:33:26,024 - stpipe.LinearityStep - INFO - LinearityStep instance created.
# 2017-08-31 13:33:26,690 - stpipe.LinearityStep - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2017-08-31 13:33:26,754 - stpipe.LinearityStep - INFO - Step LinearityStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1991467d0>,).
# 2017-08-31 13:33:27,214 - stpipe.LinearityStep - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2017-08-31 13:33:29,456 - stpipe.LinearityStep - INFO - Saving file LRS-SLIT_demo_data_step_output/linearity_out.fits
# 2017-08-31 13:33:31,709 - stpipe.LinearityStep - INFO - Step LinearityStep done

# %% [markdown]
# ### LINEARITY:  plot output science image to select pixel for inspection

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=8e3,vmax=2e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### LINEARITY:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check
pixel = [326,267]

# define group numbers for integration ramps
group = range(1,in_dm.data[0,:,pixel[0],pixel[1]].shape[0]+1,1)

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the first integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='linearity calibrated ramp')
axs[0].set_title('linearity correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## RSCD step ======================================================
# This step corrects for the slow adjustment of the reset FET to the asymtotic level after reset. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/rscd/index.html

# %% [markdown]
# ### RSCD: load module and show options

# %%
# import the step
from jwst.rscd import rscd_step

# print the description and options
print rscd_step.RSCD_Step.__doc__
print rscd_step.RSCD_Step.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     RSCD_Step: Performs an RSCD correction to MIRI data by adding a function
#     of time, frame by frame, to a copy of the input science data model.
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# #### RSCD: run step

# %%
# run the rscd step
dm = rscd_step.RSCD_Step.call(dm, save_results=True, output_dir=output_dir, output_file='rscd_out.fits')
# Out:
# 2017-08-31 13:33:33,916 - stpipe.RSCD_Step - INFO - RSCD_Step instance created.
# 2017-08-31 13:33:34,664 - stpipe.RSCD_Step - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2017-08-31 13:33:34,731 - stpipe.RSCD_Step - INFO - Step RSCD_Step running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x173072450>,).
# 2017-08-31 13:33:35,208 - stpipe.RSCD_Step - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2017-08-31 13:34:08,867 - stpipe.RSCD_Step - INFO - Saving file LRS-SLIT_demo_data_step_output/rscd_out.fits
# 2017-08-31 13:34:10,584 - stpipe.RSCD_Step - INFO - Step RSCD_Step done

# %% [markdown]
# ### RSCD:  plot output science image to select pixel for inspection

# %%
# plot--------------------------------------
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=8e3,vmax=2e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### RSCD:  input/output ramp comparison
#
# 1. plot the input and output ramps. Note that the RSCD step only corrects following a reset show will note perform a correction if there is only one integration in the exposure.
#
# 2. show the difference between the input and output ramps

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

   
# first check that there is more than one integration
if in_dm.data.shape[0] > 1:

    # plot--------------------------------------
    fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

    # plot input and output ramps of the second integration
    axs[0].plot(group, in_dm.data[-1,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input ramp')
    axs[0].plot(group, dm.data[-1,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='RSCD calibrated ramp')
    axs[0].set_title('RSCD correction',fontsize=15)
    axs[0].set_ylabel('DN',fontsize=15)
    axs[0].set_xlim(-1,max(group)+1)
    axs[0].legend(prop={'size':12}, loc=0)

    # plot ratio between the two
    axs[1].plot(group, in_dm.data[-1,:,pixel[1],pixel[0]] / dm.data[-1,:,pixel[1],pixel[0]], c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='ratio')
    axs[1].set_ylabel('DN',fontsize=15)
    axs[1].set_xlabel('group',fontsize=15)
    axs[1].legend(prop={'size':12}, loc=0)

    plt.tight_layout(h_pad=0)
    plt.show()

else: print "RSCD step only operates on exposures with more than one integration."

# %% [markdown]
# ## LASTFRAME step ==========================================
# This step corrects for the anonolous offsets in the last frame of an integration due to the way MIRI detectors reset sequentially. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/rscd/index.html

# %% [markdown]
# ### LASTFRAME: load module and show options

# %%
# import the step
from jwst.lastframe import lastframe_step

# print the description and options
print lastframe_step.LastFrameStep.__doc__
print lastframe_step.LastFrameStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     LastFrameStep: This is a MIRI specific task.  If the number of groups
#     is greater than 1, the GROUP data quality flags for the final group will
#     be set to DO_NOT_USE.
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# ### LASTFRAME: run step

# %%
# run the lastframe step
dm = lastframe_step.LastFrameStep.call(dm, save_results=True, output_dir=output_dir, output_file='lastframe_out.fits')
# Out:
# 2017-08-31 13:34:12,958 - stpipe.LastFrameStep - INFO - LastFrameStep instance created.
# 2017-08-31 13:34:13,304 - stpipe.LastFrameStep - INFO - Step LastFrameStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1186c8090>,).
# 2017-08-31 13:34:14,391 - stpipe.LastFrameStep - INFO - Saving file LRS-SLIT_demo_data_step_output/lastframe_out.fits
# 2017-08-31 13:34:16,195 - stpipe.LastFrameStep - INFO - Step LastFrameStep done

# %% [markdown]
# ### LASTFRAME:  input/output ramp comparison
#
# This correction flags the last frame of an integration so we can check that the last frame has indeed been flagged in the groupDQ extension.
#
# 1. plot the last frame of the first integration of the GROUPDQ extension, show values of flags (should be solid colour)
#
# 2. plot the input and output GROUPDQ to show that last frame has been flagged

# %%
# define an input and output integration ramp for a given pixel
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(1, 2, figsize=(10, 5))

# plot the last frame of the first integration of the GROUPDQ extension
axs[0].imshow(dm.groupdq[-1][-1], cmap='jet', interpolation='nearest', origin='lower')
axs[0].annotate('last frame of GROUPDQ', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

# determine the values in this GROUPDQ frame
flag_values = np.unique(dm.groupdq[-1][-1])
axs[0].annotate('Flag values in last frame: %s' % flag_values, xy=(0.05, 0.92), xycoords='axes fraction', fontsize=12, fontweight='bold', color='w')

# input and output ramps (setting a slight offset for the output ramp)
axs[1].plot(group, in_dm.groupdq[-1,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input flags')
axs[1].plot(group, dm.groupdq[-1,:,pixel[1],pixel[0]]+0.1, c='b', marker='o', linestyle='-', linewidth=2, label='lastframe flagged (+0.1)')
axs[1].set_title('lastframe correction',fontsize=15)
axs[1].set_ylabel('flag values',fontsize=15)
axs[1].set_xlim(-1,max(group)+1)
axs[1].set_ylim(-0.5,1.5)
axs[1].legend(prop={'size':12}, loc=2)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## DARK_CURRENT step ==========================================
#
# This step removes the dark current by subtracting a dark current reference file.
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/dark_current/index.html
#
# Note that since a dark_current was not included in the MIRISim simulations that produced the demo data, we will skip the dark_current step.

# %% [markdown]
# ### DARK_CURRENT: load module and show options

# %%
# import the step
from jwst.dark_current import dark_current_step

# print the description and options
print dark_current_step.DarkCurrentStep.__doc__
print dark_current_step.DarkCurrentStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     DarkCurrentStep: Performs dark current correction by subtracting
#     dark current reference data from the input science data model.
#
#
#         dark_output = output_file(default = None) # Dark model or averaged dark subtracted

# %% [markdown]
# ### DARK_CURRENT: run step

# %%
# run the dark_current step
dm = dark_current_step.DarkCurrentStep.call(dm, save_results=True, output_dir=output_dir, output_file='dark_current_out.fits', skip=True)
# Out:
# 2017-08-31 13:34:17,939 - stpipe.DarkCurrentStep - INFO - DarkCurrentStep instance created.
# 2017-08-31 13:34:18,314 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118a41ed0>,).
# 2017-08-31 13:34:18,315 - stpipe.DarkCurrentStep - INFO - Step skipped.
# 2017-08-31 13:34:18,323 - stpipe.DarkCurrentStep - INFO - Step DarkCurrentStep done

# %% [markdown]
# ### DARK_CURRENT:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=8e3,vmax=2e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### DARK_CURRENT:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the second integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='dark calibrated ramp')
axs[0].set_title('dark current correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference between the two
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## REFPIX step =============================================
# This step corrects for electronic drift effects in the data by applying the reference pixel correction. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/refpix/index.html

# %% [markdown]
# ### REFPIX: load module and show options

# %%
# import the step
from jwst.refpix import refpix_step

# print the description and options
print refpix_step.RefPixStep.__doc__
print refpix_step.RefPixStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     RefPixStep: Use reference pixels to correct bias drifts
#
#
#
#         odd_even_columns = boolean(default=True)
#         use_side_ref_pixels = boolean(default=True)
#         side_smoothing_length = integer(default=11)
#         side_gain = float(default=1.0)
#         odd_even_rows = boolean(default=True)

# %% [markdown]
# ### REFPIX: run step

# %%
# run the refpix step
dm = refpix_step.RefPixStep.call(dm, save_results=True, output_dir=output_dir, output_file='refpix_out.fits')
# Out:
# 2017-08-31 13:34:20,300 - stpipe.RefPixStep - INFO - RefPixStep instance created.
# 2017-08-31 13:34:20,936 - stpipe.RefPixStep - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-31 13:34:21,004 - stpipe.RefPixStep - INFO - Step RefPixStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118a41ed0>,).
# 2017-08-31 13:34:21,137 - stpipe.RefPixStep - INFO - use_side_ref_pixels = True
# 2017-08-31 13:34:21,139 - stpipe.RefPixStep - INFO - odd_even_columns = True
# 2017-08-31 13:34:21,140 - stpipe.RefPixStep - INFO - side_smoothing_length = 11
# 2017-08-31 13:34:21,141 - stpipe.RefPixStep - INFO - side_gain = 1.000000
# 2017-08-31 13:34:21,142 - stpipe.RefPixStep - INFO - odd_even_rows = True
# 2017-08-31 13:34:21,144 - stpipe.RefPixStep - INFO - Subtracting initial read from each integration
# 2017-08-31 13:34:22,567 - stpipe.RefPixStep - INFO - Adding initial read back in
# 2017-08-31 13:34:24,472 - stpipe.RefPixStep - INFO - Saving file LRS-SLIT_demo_data_step_output/refpix_out.fits
# 2017-08-31 13:34:26,265 - stpipe.RefPixStep - INFO - Step RefPixStep done

# %% [markdown]
# ### REFPIX:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=8e3,vmax=2e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### REFPIX:  input/output ramp comparison
#
# 1. plot the input and output ramps
#
# 2. show the difference between these

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]


# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# plot input and output ramps of the second integration
axs[0].plot(group, in_dm.data[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input ramp')
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='refpix calibrated ramp')
axs[0].set_title('refpix correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].legend(prop={'size':12}, loc=0)

# plot difference between the two
axs[1].plot(group, in_dm.data[0,:,pixel[1],pixel[0]] - dm.data[0,:,pixel[1],pixel[0]], c='g', marker='s', markersize=6, linestyle='-', linewidth=2, label='difference')
axs[1].set_ylabel('DN',fontsize=15)
axs[1].set_xlabel('group',fontsize=15)
axs[1].legend(prop={'size':12}, loc=0)

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## JUMP correction =================================================
#
# This step detects jumps in the ramp by looking for outliers from the ramp. It updates the GROUPDQ array to indicate where a jump was found.
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/jump/index.html

# %% [markdown]
# ### JUMP: load module and show options

# %%
# import the step
from jwst.jump import jump_step

# print the description and options
print jump_step.JumpStep.__doc__
print jump_step.JumpStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     JumpStep: Performs CR/jump detection on each ramp integration within an
#     exposure. The 2-point difference method is applied.
#
#
#         rejection_threshold = float(default=4.0,min=0) # CR rejection threshold

# %% [markdown]
# ### JUMP: run step

# %%
# run the jump step
dm = jump_step.JumpStep.call(dm, save_results=True, output_dir=output_dir, output_file='jump_out.fits')
# Out:
# 2017-08-31 13:34:28,321 - stpipe.JumpStep - INFO - JumpStep instance created.
# 2017-08-31 13:34:28,975 - stpipe.JumpStep - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-08-31 13:34:28,977 - stpipe.JumpStep - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-08-31 13:34:29,045 - stpipe.JumpStep - INFO - Step JumpStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x157438110>,).
# 2017-08-31 13:34:29,176 - stpipe.JumpStep - INFO - CR rejection threshold = 4 sigma
# 2017-08-31 13:34:29,523 - stpipe.JumpStep - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-08-31 13:34:29,890 - stpipe.JumpStep - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-08-31 13:34:31,172 - stpipe.JumpStep - INFO - Executing two-point difference method
# 2017-08-31 13:35:00,696 - stpipe.JumpStep - INFO - Saving file LRS-SLIT_demo_data_step_output/jump_out.fits
# 2017-08-31 13:35:02,923 - stpipe.JumpStep - INFO - Step JumpStep done

# %% [markdown]
# ### JUMP:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=8e3,vmax=2e4))
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### JUMP:  input/output ramp comparison
#
# 1. plot the output ramp
#
# 2. show the input and output GROUPDQ vectors and mark where jumps were detected (a flag of >=4 in GROUPDQ)

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# plot--------------------------------------
fig, axs = plt.subplots(2, 1, figsize=(10, 8), sharex=True)

# first integration for input/output ramps
axs[0].plot(group, dm.data[0,:,pixel[1],pixel[0]], c='b', marker='o', linestyle='-', linewidth=2, label='ramp')
axs[0].set_title('jump correction',fontsize=15)
axs[0].set_ylabel('DN',fontsize=15)
axs[0].set_xlim(-1,max(group)+1)
axs[0].set_ylim(min(dm.data[0,:,pixel[1],pixel[0]])-200,max(dm.data[0,:,pixel[1],pixel[0]])+200)
axs[0].legend(prop={'size':12}, loc=2)

# input and output flag values (setting a slight offset for the output flags)
axs[1].plot(group, in_dm.groupdq[0,:,pixel[1],pixel[0]], c='r', marker='^', markersize=6, linestyle='-', linewidth=2, label='input flags')
axs[1].plot(group, dm.groupdq[0,:,pixel[1],pixel[0]]+0.1, c='b', marker='o', linestyle='-', linewidth=2, label='jump flagged (+0.1)')
axs[1].plot([-10,100],[4,4], linestyle='--', linewidth=3, c='g', label='jump threshold')
axs[1].set_ylabel('flag values',fontsize=15)
axs[1].set_ylabel('group dq',fontsize=15)
axs[1].set_xlim(-1,max(group)+1)
axs[1].set_ylim(-0.5,6.5)
axs[1].legend(prop={'size':12}, loc=2)

# draw lines to show the groups which have been flagged as jumps
for n, val in enumerate(group):
    if (dm.groupdq[0,n,pixel[1],pixel[0]] >= 4): 
        axs[0].plot([n+1,n+1],[min(dm.data[0,:,pixel[1],pixel[0]])-200,max(dm.data[0,:,pixel[1],pixel[0]])+200], linestyle='--', linewidth=0.3, c='k')
        axs[1].plot([n+1,n+1],[-1,6], linestyle='--', linewidth=0.3, c='k')

plt.tight_layout(h_pad=0)
plt.show()

# %% [markdown]
# ## RAMP_FITTING step =========================================
#
# This step caculates the mean count rate for each pixel by performing a linear fit to the ramps. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/ramp_fitting/index.html
#
# There are two outputs are here:
#
# 1) the slope image  (_rate.fits)
#
# 2) if more than one integration, slope image per integration  (_rateints.fits)

# %% [markdown]
# ### RAMP_FITTING: load module and show options

# %%
# import the step
from jwst.ramp_fitting import ramp_fit_step

# print the description and options
print ramp_fit_step.RampFitStep.__doc__
print ramp_fit_step.RampFitStep.spec
# Out:
#     This step fits a straight line to the value of counts vs. time to
#     determine the mean count rate for each pixel.
#
#
#         int_name = string(default='')
#         save_opt = boolean(default=False) # Save optional output
#         opt_name = string(default='')

# %% [markdown]
# ### RAMP_FITTING: run step

# %%
# run the ramp_fitting step
dm = ramp_fit_step.RampFitStep.call(dm, save_results=True, output_dir=output_dir)

# copy datamodel for comparison later
level2A_dm = dm.copy()
# Out:
# 2017-08-31 13:35:03,772 - stpipe.RampFitStep - INFO - RampFitStep instance created.
# 2017-08-31 13:35:04,569 - stpipe.RampFitStep - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-08-31 13:35:04,570 - stpipe.RampFitStep - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-08-31 13:35:04,641 - stpipe.RampFitStep - INFO - Step RampFitStep running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10b6a76d0>,).
# 2017-08-31 13:35:05,523 - stpipe.RampFitStep - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-08-31 13:35:05,559 - stpipe.RampFitStep - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-08-31 13:35:05,587 - stpipe.RampFitStep - INFO - Using algorithm = ols
# 2017-08-31 13:35:05,589 - stpipe.RampFitStep - INFO - Using weighting = optimal
# 2017-08-31 13:35:05,609 - stpipe.RampFitStep - INFO - Effective integration time per group: 2.77504
# 2017-08-31 13:36:59,334 - stpipe.RampFitStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/jwst-0.7.8rc2-py2.7-macosx-10.7-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:1991: RuntimeWarning: invalid value encountered in sqrt
#   new_var = np.sqrt(poiss_2d + rn_2d**2.)
#
# 2017-08-31 13:38:24,142 - stpipe.RampFitStep - INFO - Number of groups per integration: 50
# 2017-08-31 13:38:24,143 - stpipe.RampFitStep - INFO - Number of integrations: 2
# 2017-08-31 13:38:24,331 - stpipe.RampFitStep - INFO - Step.save_model LRS-SLIT_demo_data_step_output/jump_out_rateints.fits
# 2017-08-31 13:38:24,516 - stpipe.RampFitStep - INFO - Saving file LRS-SLIT_demo_data_step_output/jump_out_rampfitstep.fits
# 2017-08-31 13:38:24,619 - stpipe.RampFitStep - INFO - Step RampFitStep done

# %% [markdown]
# ### RAMP_FITTING:  level 1B and level 2A image comparison
#
# Visually compare the input ramp and the output slope image

# %%
# open the level 1B input as a jwst data model
with datamodels.open(input_file) as in_dm:

    # plot--------------------------------------
    # show the input ramp image and the calibrated
    # slope image.
    fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

    # sum the groups in the first integration of the input ramp image and plot
    axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
    axs[0].annotate('Input ramp image (level 1B)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[0].set_facecolor('black')
    axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=20)
    axs[1].annotate('Slope image (level 2A)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
    axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## Run level 2A pipeline on background exposure

# %%
from jwst.pipeline import SloperPipeline

dm_2A_bkg = SloperPipeline.call(bkg_file, save_results=True, output_dir=output_dir, steps={'dark_current':{'skip':True}})
# Out:
# 2017-08-31 13:38:27,516 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-08-31 13:38:27,519 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-08-31 13:38:27,521 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-08-31 13:38:27,523 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-08-31 13:38:27,526 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-08-31 13:38:27,529 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-08-31 13:38:27,531 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-08-31 13:38:27,533 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-08-31 13:38:27,536 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-08-31 13:38:27,538 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-08-31 13:38:27,539 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-08-31 13:38:27,543 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-08-31 13:38:27,546 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-08-31 13:38:27,548 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-08-31 13:38:27,708 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('LRS-SLIT_demo_data/bkg_MIRIMAGE_P750Lexp1.fits',).
# 2017-08-31 13:38:27,710 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-08-31 13:38:29,106 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x11967a350>,).
# 2017-08-31 13:38:29,242 - stpipe.SloperPipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2017-08-31 13:38:29,243 - stpipe.SloperPipeline.group_scale - WARNING - Step will be skipped
# 2017-08-31 13:38:29,250 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale done
# 2017-08-31 13:38:29,814 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits'.
# 2017-08-31 13:38:29,919 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118b50390>,).
# 2017-08-31 13:38:30,431 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0019.fits
# 2017-08-31 13:38:31,671 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-08-31 13:38:32,355 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits'.
# 2017-08-31 13:38:32,434 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x119a164d0>,).
# 2017-08-31 13:38:32,933 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0019.fits
# 2017-08-31 13:38:34,485 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-08-31 13:38:35,218 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0009.fits'.
# 2017-08-31 13:38:35,292 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x119bb2050>,).
# 2017-08-31 13:38:35,784 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0009.fits
# 2017-08-31 13:38:39,732 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-08-31 13:38:40,426 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits'.
# 2017-08-31 13:38:40,501 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118a45c50>,).
# 2017-08-31 13:38:41,009 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0024.fits
# 2017-08-31 13:38:43,524 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-08-31 13:38:44,248 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits'.
# 2017-08-31 13:38:44,321 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x119a2ced0>,).
# 2017-08-31 13:38:44,805 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0004.fits
# 2017-08-31 13:39:18,465 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-08-31 13:39:18,690 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x119b221d0>,).
# 2017-08-31 13:39:19,707 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-08-31 13:39:19,923 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x17308a250>,).
# 2017-08-31 13:39:19,924 - stpipe.SloperPipeline.dark_current - INFO - Step skipped.
# 2017-08-31 13:39:19,932 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-08-31 13:39:20,494 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-31 13:39:20,568 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x17308a250>,).
# 2017-08-31 13:39:20,703 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-08-31 13:39:20,704 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-08-31 13:39:20,705 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-08-31 13:39:20,706 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-08-31 13:39:20,708 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-08-31 13:39:20,709 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-08-31 13:39:22,126 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-08-31 13:39:24,005 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-08-31 13:39:24,713 - stpipe.SloperPipeline.persistence - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2017-08-31 13:39:24,714 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2017-08-31 13:39:24,715 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2017-08-31 13:39:24,790 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x118b68f50>,).
# 2017-08-31 13:39:26,910 - stpipe.SloperPipeline.persistence - WARNING - Missing reference file types:  PERSAT TRAPDENSITY TRAPPARS
# 2017-08-31 13:39:26,921 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-08-31 13:39:27,660 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-08-31 13:39:27,661 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-08-31 13:39:27,737 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1730a2bd0>,).
# 2017-08-31 13:39:27,879 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-08-31 13:39:28,282 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-08-31 13:39:28,690 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-08-31 13:39:29,919 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-08-31 13:39:49,055 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-08-31 13:39:49,763 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits'.
# 2017-08-31 13:39:49,764 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits'.
# 2017-08-31 13:39:49,843 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1189ad3d0>,).
# 2017-08-31 13:39:50,738 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0040.fits
# 2017-08-31 13:39:50,770 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0008.fits
# 2017-08-31 13:39:50,800 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-08-31 13:39:50,802 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-08-31 13:39:50,832 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-08-31 13:42:59,602 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-08-31 13:42:59,603 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-08-31 13:42:59,780 - stpipe.SloperPipeline.ramp_fit - INFO - Step.save_model LRS-SLIT_demo_data_step_output/bkg_MIRIMAGE_P750Lexp1_rateints.fits
# 2017-08-31 13:42:59,925 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-08-31 13:42:59,926 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-08-31 13:42:59,934 - stpipe.SloperPipeline - INFO - Saving file LRS-SLIT_demo_data_step_output/bkg_MIRIMAGE_P750Lexp1_rate.fits
# 2017-08-31 13:43:00,045 - stpipe.SloperPipeline - INFO - Step SloperPipeline done

# %% [markdown]
# ## ASSIGN_WCS step =================================================
# This step creates a WCS object and associates it with the science file, mapping detector to world coordinates. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/assign_wcs/index.html

# %%
# import the step
from jwst.assign_wcs import assign_wcs_step

# print the description and options
print assign_wcs_step.AssignWcsStep.__doc__
print assign_wcs_step.AssignWcsStep.spec
# Out:
#     AssignWcsStep: Loads all WCS and distortion information for an exposure
#     and stores it in the model meta data.

# %% [markdown]
# ### ASSIGN_WCS: run step

# %%
# run the assign_wcs step
dm = assign_wcs_step.AssignWcsStep.call(dm, save_results=True, output_dir=output_dir, output_file='assign_wcs_out.fits')
# Out:
# 2017-08-31 13:43:00,061 - stpipe.AssignWcsStep - INFO - AssignWcsStep instance created.
# 2017-08-31 13:43:00,805 - stpipe.AssignWcsStep - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-08-31 13:43:00,806 - stpipe.AssignWcsStep - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-08-31 13:43:00,807 - stpipe.AssignWcsStep - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-08-31 13:43:00,808 - stpipe.AssignWcsStep - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf'.
# 2017-08-31 13:43:00,810 - stpipe.AssignWcsStep - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-08-31 13:43:00,811 - stpipe.AssignWcsStep - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-08-31 13:43:00,812 - stpipe.AssignWcsStep - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-08-31 13:43:00,813 - stpipe.AssignWcsStep - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-08-31 13:43:00,814 - stpipe.AssignWcsStep - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-08-31 13:43:00,815 - stpipe.AssignWcsStep - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-08-31 13:43:00,817 - stpipe.AssignWcsStep - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-08-31 13:43:00,818 - stpipe.AssignWcsStep - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-08-31 13:43:00,819 - stpipe.AssignWcsStep - INFO - Prefetch for REGIONS reference file is 'N/A'.
# 2017-08-31 13:43:00,820 - stpipe.AssignWcsStep - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0001.fits'.
# 2017-08-31 13:43:00,821 - stpipe.AssignWcsStep - INFO - Prefetch for V2V3 reference file is 'N/A'.
# 2017-08-31 13:43:00,822 - stpipe.AssignWcsStep - INFO - Prefetch for WAVELENGTHRANGE reference file is 'N/A'.
# 2017-08-31 13:43:00,908 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep running with args (<jwst.datamodels.image.ImageModel object at 0x119b229d0>,).
# 2017-08-31 13:43:06,312 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,314 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,316 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/remap_axes' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,318 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,320 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,322 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/remap_axes' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,323 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,325 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,326 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/scale' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,328 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/scale' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,329 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,330 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,332 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:06,333 - stpipe.AssignWcsStep - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0023.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-31 13:43:07,275 - stpipe.AssignWcsStep - INFO - COMPLETED assign_wcs
# 2017-08-31 13:43:07,306 - stpipe.AssignWcsStep - INFO - Saving file LRS-SLIT_demo_data_step_output/assign_wcs_out.fits
# 2017-08-31 13:43:07,529 - stpipe.AssignWcsStep - INFO - Step AssignWcsStep done

# %% [markdown]
# ### ASSIGN_WCS:  plot output science image to select pixel for inspection

# %%
fig, axs = plt.subplots(1, 1, figsize=(8, 8))

# show last frame of first integration
axs.imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs.annotate('SCI', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### ASSIGN_WCS: perform some transforms
#
# 1. Display the available coordinate frames
#
# 2. perform some transfer from pixel to WCS

# %%
# using image in previous cell, select pixel to check, 
# comment out if you want to use pixel defined earlier
#pixel = [560,237]

# print available coordinate frames
print "Available coordinate frames:" 
print(", ".join(dm.meta.wcs.available_frames))
print ""

# perform transforms on pixel
ra, dec, wav = dm.meta.wcs(pixel[0],pixel[1])

print "Pixel: %d, %d" % (pixel[0],pixel[1])
print "assign_wcs RA, DEC (deg): %0.7f %0.7f" % (ra,dec)
print "assing_wcs Wavelength (micron): %0.3f" % wav
# Out:
# Available coordinate frames:
# detector, world
#
# Pixel: 326, 267
# assign_wcs RA, DEC (deg): 0.0091063 -0.0008407
# assing_wcs Wavelength (micron): 9.251

# %% [markdown]
# ## BACKGROUND step =============================================
# The background step subtracts a dedicated background exposure from the target exposure.
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/background/index.html

# %% [markdown]
# ### BACKGROUND: load module and show options

# %%
# import the step
from jwst.background import background_step

# print the description and options
print background_step.BackgroundStep.__doc__
print background_step.BackgroundStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     BackgroundStep:  Subtract background exposures from target exposures.

# %% [markdown]
# ### BACKGROUND: run step

# %%
# run the background step
dm = background_step.BackgroundStep.call(dm, [dm_2A_bkg], save_results=True, output_dir=output_dir, output_file='background_out.fits')
# Out:
# 2017-08-31 13:43:08,126 - stpipe.BackgroundStep - INFO - BackgroundStep instance created.
# 2017-08-31 13:43:08,327 - stpipe.BackgroundStep - INFO - Step BackgroundStep running with args (<jwst.datamodels.image.ImageModel object at 0x11913c6d0>, [<jwst.datamodels.image.ImageModel object at 0x10bd6bad0>]).
# 2017-08-31 13:43:08,877 - stpipe.BackgroundStep - INFO - Saving file LRS-SLIT_demo_data_step_output/background_out.fits
# 2017-08-31 13:43:09,090 - stpipe.BackgroundStep - INFO - Step BackgroundStep done

# %% [markdown]
# ### BACKGROUND: check input/output images

# %%
fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# sum the groups in the first integration of the input ramp image and plot
axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=20)
axs[0].annotate('Input', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=20)
axs[1].annotate('Background subtracted', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# ## FLAT_FIELD step =============================================
# The flat_field step divides the image by a flat-field reference image and updates the DQ array to indicate where no flat-field is available for a pixel. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/flatfield/index.html

# %% [markdown]
# ### FLAT_FIELD: load module and show options

# %%
# import the step
from jwst.flatfield import flat_field_step

# print the description and options
print flat_field_step.FlatFieldStep.__doc__
print flat_field_step.FlatFieldStep.spec

# copy the datamodel for input/output comparison
in_dm = dm.copy()
# Out:
#     FlatFieldStep: Flat-field a science image using a flatfield reference image.
#
#
#         # Suffix for optional output file for interpolated flat fields.
#         # Note that this is only used for NIRSpec spectrographic data.
#         flat_suffix = string(default=None)

# %% [markdown]
# ### FLAT_FIELD: run step

# %%
# run the flat_field step
dm = flat_field_step.FlatFieldStep.call(dm, save_results=True, output_dir=output_dir, output_file='flatfield_out.fits')
# Out:
# 2017-08-31 13:43:09,852 - stpipe.FlatFieldStep - INFO - FlatFieldStep instance created.
# 2017-08-31 13:43:10,426 - stpipe.FlatFieldStep - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-08-31 13:43:10,427 - stpipe.FlatFieldStep - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-08-31 13:43:10,428 - stpipe.FlatFieldStep - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0244.fits'.
# 2017-08-31 13:43:10,429 - stpipe.FlatFieldStep - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-08-31 13:43:10,504 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep running with args (<jwst.datamodels.image.ImageModel object at 0x10bd44410>,).
# 2017-08-31 13:43:11,119 - stpipe.FlatFieldStep - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-31 13:43:11,121 - stpipe.FlatFieldStep - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-31 13:43:11,122 - stpipe.FlatFieldStep - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-31 13:43:11,128 - stpipe.FlatFieldStep - WARNING - Keyword DIFF_PATTERN does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-31 13:43:11,379 - stpipe.FlatFieldStep - INFO - Saving file LRS-SLIT_demo_data_step_output/flatfield_out.fits
# 2017-08-31 13:43:11,576 - stpipe.FlatFieldStep - INFO - Step FlatFieldStep done

# %% [markdown]
# ### FLAT_FIELD: input/output image checks
#
# 1. Display the input and output images
# 2. Show the ratio of the two

# %%
# plot--------------------------------------
# show the input, output and ratio image, 
# which will correspond to the flat field.
fig, axs = plt.subplots(1, 3, figsize=(14, 5),sharey=True)

# show the input
axs[0].imshow(in_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[0].annotate('Input slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')

axs[1].imshow(dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=-1, vmax=10)
axs[1].annotate('Flat-fielded slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

axs[2].imshow(in_dm.data / dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0.98, vmax=1.02)
axs[2].annotate('Ratio image (flat field)', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[2].set_facecolor('black')

plt.tight_layout()
plt.show()
# Out:
# 2017-08-31 13:43:11,730 - stpipe - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/ipykernel_launcher.py:15: RuntimeWarning: invalid value encountered in divide
#   from ipykernel import kernelapp as app

# %% [markdown]
# ## SRCTYPE step =======================================
# This step checks or sets whether a spectroscopic source should be treated as a point or extended object, writing the appropriate value to a keyword. Allowable values are POINT, EXTENDED and UNKNOWN. This will usually be set from the APT by an observer. If the user sets UNKNOWN, a default of POINT is set for the LRS. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/srctype/index.html

# %% [markdown]
# ### SRCTYPE: load module and show options

# %%
# import the step
from jwst.srctype import srctype_step

# print the description and options
print srctype_step.SourceTypeStep.__doc__
print srctype_step.SourceTypeStep.spec
# Out:
#     SourceTypeStep: Selects and sets a source type based on various inputs.
#     The source type is used in later calibrations to determine the appropriate
#     methods to use. Input comes from either the SRCTYPE keyword value, which
#     is populated from user info in the APT, or the NIRSpec MSA planning tool.

# %% [markdown]
# ### SRCTYPE: run custom step
# The srctype task can not be run as a standalone step at the moment. What follows is some simple code that does the same job, ie, writes the srctype keyword with the default LRS value 'POINT'

# %%
# run the srctype step
dm = srctype_step.SourceTypeStep.call(dm, save_results=True, output_dir=output_dir, output_file='srctype_out.fits')
# Out:
# 2017-08-31 13:43:12,183 - stpipe.SourceTypeStep - INFO - SourceTypeStep instance created.
# 2017-08-31 13:43:12,297 - stpipe.SourceTypeStep - INFO - Step SourceTypeStep running with args (<jwst.datamodels.image.ImageModel object at 0x197b9a050>,).
# 2017-08-31 13:43:12,429 - stpipe.SourceTypeStep - INFO - Input EXP_TYPE is MIR_LRS-FIXEDSLIT
# 2017-08-31 13:43:12,431 - stpipe.SourceTypeStep - INFO - Input SRCTYPE is unknown. Setting to default value of POINT
# 2017-08-31 13:43:12,459 - stpipe.SourceTypeStep - INFO - Saving file LRS-SLIT_demo_data_step_output/srctype_out.fits
# 2017-08-31 13:43:12,686 - stpipe.SourceTypeStep - INFO - Step SourceTypeStep done

# %% [markdown]
# ### SRCTYPE: check the SRCTYPE keyword value

# %%
# print the value of the srctype keyword
print "SRCTYPE: %s" % dm.meta.target.source_type
# Out:
# SRCTYPE: POINT

# %% [markdown]
# ## PHOTOM step =======================================
# This step uses spectroscopic photometric conversion reference files to convert count rates to absolute flux units. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/photom/index.html
#
# This is the last step in the level 2b pipeline.

# %% [markdown]
# ### PHOTOM: load module and show options

# %%
# import the step
from jwst.photom import photom_step

# print the description and options
print photom_step.PhotomStep.__doc__
print photom_step.PhotomStep.spec
# Out:
#     PhotomStep: Module for loading photometric conversion infomation from
#         reference files and attaching or applying them to the input science
#         data model
#
#
#     pre_hooks = string_list(default=list())
#     post_hooks = string_list(default=list())
#     output_dir = string(default=None)       # Directory path for output files
#     output_file = output_file(default=None) # File to save output to.
#     skip = boolean(default=False)           # Skip this step
#     save_results = boolean(default=False)   # Force save results
#     suffix = string(default=None)           # Default suffix for output files

# %% [markdown]
# ### PHOTOM: run step

# %%
dm = photom_step.PhotomStep.call(dm, save_results=True, output_dir=output_dir, output_file='photom_out.fits')
# Out:
# 2017-08-31 13:43:12,711 - stpipe.PhotomStep - INFO - PhotomStep instance created.
# 2017-08-31 13:43:13,297 - stpipe.PhotomStep - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-08-31 13:43:13,298 - stpipe.PhotomStep - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits'.
# 2017-08-31 13:43:13,377 - stpipe.PhotomStep - INFO - Step PhotomStep running with args (<jwst.datamodels.image.ImageModel object at 0x11af75790>,).
# 2017-08-31 13:43:13,897 - stpipe.PhotomStep - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0014.fits
# 2017-08-31 13:43:14,317 - stpipe.PhotomStep - INFO - Using area reference file: N/A
# 2017-08-31 13:43:14,319 - stpipe.PhotomStep - INFO - Using instrument: MIRI
# 2017-08-31 13:43:14,320 - stpipe.PhotomStep - INFO -  detector: MIRIMAGE
# 2017-08-31 13:43:14,321 - stpipe.PhotomStep - INFO -  exp_type: MIR_LRS-FIXEDSLIT
# 2017-08-31 13:43:14,322 - stpipe.PhotomStep - INFO -  filter: P750L
# 2017-08-31 13:43:14,382 - stpipe.PhotomStep - INFO -  subarray: FULL
# 2017-08-31 13:43:14,403 - stpipe.PhotomStep - INFO - Relative response table written.
# 2017-08-31 13:43:14,404 - stpipe.PhotomStep - INFO - Writing PHOTMJSR with value: 1
# 2017-08-31 13:43:14,438 - stpipe.PhotomStep - INFO - Saving file LRS-SLIT_demo_data_step_output/photom_out.fits
# 2017-08-31 13:43:14,672 - stpipe.PhotomStep - INFO - Step PhotomStep done

# %% [markdown]
# ### PHOTOM: check the correct photometric keywords in output header
#
# 1. Get the photometric information from the output header

# %%
print "Photometric conversions (Flux density producing 1 cps)"
print "%0.2e microJy/arcsec^2" % dm.meta.photometry.conversion_microjanskys
print "%0.2e MJy/sr" % dm.meta.photometry.conversion_megajanskys
# Out:
# Photometric conversions (Flux density producing 1 cps)
# 2.35e+01 microJy/arcsec^2
# 1.00e+00 MJy/sr

# %% [markdown]
# ## EXTRACT_1D step ======================================
# This step extracts a 1D spectrum from the cube. See:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/extract_1d/index.html

# %% [markdown]
# ### EXTRACT_1D: load module and show options

# %%
# import the step
from jwst.extract_1d import extract_1d_step

# print the description and options
print extract_1d_step.Extract1dStep.__doc__
print extract_1d_step.Extract1dStep.spec
# Out:
#     Extract1dStep: Extract a 1-d spectrum from 2-d data
#
#
#     # Boxcar smoothing width for background regions.
#     smoothing_length = integer(default=None)
#     # Order of polynomial fit to one column (or row if the dispersion
#     # direction is vertical) of background regions.
#     bkg_order = integer(default=None, min=0)

# %% [markdown]
# ### EXTRACT_1D: run step

# %%
spec_dm = extract_1d_step.Extract1dStep.call(dm, save_results=True, output_dir=output_dir, output_file='extract_1d_out.fits')
# Out:
# 2017-08-31 13:43:14,695 - stpipe.Extract1dStep - INFO - Extract1dStep instance created.
# 2017-08-31 13:43:15,312 - stpipe.Extract1dStep - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json'.
# 2017-08-31 13:43:15,403 - stpipe.Extract1dStep - INFO - Step Extract1dStep running with args (<jwst.datamodels.image.ImageModel object at 0x11b0b7690>,).
# 2017-08-31 13:43:15,936 - stpipe.Extract1dStep - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0004.json
# 2017-08-31 13:43:16,077 - stpipe.Extract1dStep - WARNING - 1 NaNs in wavelength array; set to 0.01
# 2017-08-31 13:43:16,102 - stpipe.Extract1dStep - WARNING - Using RELSENS, 388 elements were extrapolated; these values will be set to 1.
# 2017-08-31 13:43:16,322 - stpipe.Extract1dStep - INFO - Saving file LRS-SLIT_demo_data_step_output/extract_1d_out.fits
# 2017-08-31 13:43:16,430 - stpipe.Extract1dStep - INFO - Step Extract1dStep done

# %% [markdown]
# ### EXTRACT_1D: plot spectrum

# %%
# plot--------------------------------------
# simple XY plot of the spectrum
fig, axs = plt.subplots(1, 1, figsize=(10, 7))

spec = spec_dm.spec[0]

axs.plot(spec.spec_table['WAVELENGTH'][1:-1], spec.spec_table['FLUX'][1:-1], c='b', marker='.', markersize=0,
         linestyle='-', linewidth=2)
axs.set_ylabel(r'Flux ($\mu$Jy)')
axs.set_xlabel(r'Wavelength ($\mu$m)')

plt.show()
