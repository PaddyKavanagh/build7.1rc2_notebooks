# %% [markdown]
# # Run level 2A, 2B and 3 pipelines on MRS data using jwst.pipeline classes

# %% [markdown]
# ### by Patrick Kavanagh (DIAS, Ireland) August 18th 2017

# %% [markdown]
# This notebook demonstrates the execution of the level 2A and 2B pipelines for MRS data in Python using the jwst.pipeline classes.
#
# For a description of the pipeline classes see:
#
# http://ssb.stsci.edu/doc/jwst_dev/jwst/pipeline/index.html
#
# The files used in this notebook is a MIRISim simulation of a point source with a 300 K blackbody plus emission lines spectrum
#
# The simulated observation is a four-point dither on the source with the channels 1 and 2, and the SHORT disperser.

# %% [markdown]
# #### Imports

# %%
import os, glob, shutil

import numpy as np
from astropy.io import fits
from matplotlib.colors import LogNorm
import matplotlib.pyplot as plt
from subprocess import call

from jwst import datamodels

# %matplotlib inline
# %matplotlib notebook # if you want interactive plots

# %% [markdown]
# #### Set input file:

# %%
# set input filenames and directory. In this example, the files are located in a folder called 'MRS_demo_data'
input_dir = 'MRS_demo_data'
input_files = glob.glob(os.path.join(input_dir,'*.fits'))

# set the output directory name
output_dir = input_dir + '_pipelined'

# if the output directory exists, delete it
if os.path.exists(output_dir): shutil.rmtree(output_dir)

# create the output directory
os.mkdir(output_dir)

# %% [markdown]
# #### print some information about the input files. We will just look at the first file

# %%
# print some info on input file
with fits.open(input_files[0]) as hdulist:
    
    if hdulist[0].header['ORIGIN'] == 'STScI':
        # specific information on instrument/exposure
        identifier = hdulist[0].header['OBS_ID']
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t\t\t\t Detector\t nInts\t nGrps\t rdPatt\t subAr\t chan.\t band"
        print "--------------------------------------------------------------------------------------------------"
        print "%s\t %s\t %d\t %s\t %s\t %s\t %s\t %s" % (identifier,detector,nInts,nGroups,readPatt,subArr,channel,band)
        print "\n\n"
        
    else:
        # specific information on instrument/exposure
        detector = hdulist[0].header['DETECTOR']
        nInts = hdulist[0].header['NINTS']
        nGroups = hdulist[0].header['NGROUPS']
        readPatt = hdulist[0].header['READPATT']
        expTime = hdulist[0].header['EFFEXPTM']
        subArr = hdulist[0].header['SUBARRAY']
        channel = hdulist[0].header['CHANNEL']
        band = hdulist[0].header['BAND']
        print "ID\t Detector\t nInts\t nGrps\t rdPatt\t chan.\t band"
        print "--------------------------------------------------------------------------------------------------"
        print "MIRISim\t %s\t %d\t %s\t %s\t %s\t %s" % (detector,nInts,nGroups,readPatt,channel,band)
        print "\n\n"

    # fits extension table
    hdulist.info()
# Out:
# ID	 Detector	 nInts	 nGrps	 rdPatt	 chan.	 band
# --------------------------------------------------------------------------------------------------
# MIRISim	 MIRIFUSHORT	 2	 50	 FAST	 12	 SHORT
#
#
#
# Filename: MRS_demo_data/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits
# No.    Name      Ver    Type      Cards   Dimensions   Format
#   0  PRIMARY       1 PrimaryHDU     148   ()
#   1  SCI           1 ImageHDU        14   (1032, 1024, 50, 2)   float32
#   2  REFOUT        1 ImageHDU        14   (258, 1024, 50, 2)   float32
#   3  PIXELDQ       1 ImageHDU        10   (1032, 1024)   int32 (rescales to uint32)
#   4  PIXELDQ_DEF    1 BinTableHDU     17   29R x 4C   [J, J, 40A, 128A]
#   5  ASDF          1 ImageHDU         7   (533679068,)   uint8

# %% [markdown]
# #### show the last frame of the first integration for each file

# %%
fig, axs = plt.subplots(2, 2, figsize=(12, 12))
axs = axs.ravel()

i = 0
for input_file in input_files:
    # open the input image as a jwst data model
    with datamodels.open(input_file) as in_dm:

        dith_num = i+1
        axs[i].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=3e4))
        axs[i].annotate('Dither %d' % dith_num, xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[i].set_facecolor('black')
        i += 1

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Level 2A pipeline (ramps-to-slopes)

# %% [markdown]
# #### import the level 2A pipeline class and print description

# %%
from jwst.pipeline import SloperPipeline
print SloperPipeline.__doc__
# Out:
#     SloperPipeline: Apply all calibration steps to raw JWST
#     ramps to produce a 2-D slope product. Included steps are:
#     group_scale, dq_init, saturation, ipc, superbias, refpix, rscd,
#     lastframe, linearity, dark_current, persistence, jump detection,
#     and ramp_fit.

# %% [markdown]
# For MIRI, the steps in order are: dq_init, saturation, linearity, RSCD, lastframe, dark_current, refpix, jump, ramp_fitting

# %% [markdown]
# #### run pipeline
# We pass the level 1B files (demo data). The output level 2A files will be saved in the output_dir as '*_rate.fits'
#
# NOTE: As dark current was switched off in the MIRISim simulations that produced the demo data, we will skip the dark_current step in the call to the SloperPipeline

# %%
for input_file in input_files:
    dm_2A = SloperPipeline.call(input_file, save_results=True, output_dir=output_dir, steps={'dark_current':{'skip':True}})
# Out:
# 2017-08-26 16:03:00,019 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-08-26 16:03:00,021 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-08-26 16:03:00,023 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-08-26 16:03:00,025 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-08-26 16:03:00,027 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-08-26 16:03:00,033 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-08-26 16:03:00,037 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-08-26 16:03:00,038 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-08-26 16:03:00,041 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-08-26 16:03:00,042 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-08-26 16:03:00,045 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-08-26 16:03:00,047 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-08-26 16:03:00,050 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-08-26 16:03:00,052 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-08-26 16:03:00,136 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('MRS_demo_data/det_image_seq1_MIRIFUSHORT_12SHORTexp1.fits',).
# 2017-08-26 16:03:00,137 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-08-26 16:03:01,752 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x20fff9a90>,).
# 2017-08-26 16:03:01,896 - stpipe.SloperPipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2017-08-26 16:03:01,897 - stpipe.SloperPipeline.group_scale - WARNING - Step will be skipped
# 2017-08-26 16:03:01,904 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale done
# 2017-08-26 16:03:04,305 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-08-26 16:03:04,388 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f1f8bd0>,).
# 2017-08-26 16:03:04,898 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2017-08-26 16:03:08,384 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-08-26 16:03:09,170 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-08-26 16:03:09,257 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10dabf3d0>,).
# 2017-08-26 16:03:09,767 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2017-08-26 16:03:11,922 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-08-26 16:03:12,614 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-08-26 16:03:12,691 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f20c750>,).
# 2017-08-26 16:03:13,167 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits
# 2017-08-26 16:03:17,464 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-08-26 16:03:18,179 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2017-08-26 16:03:18,251 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x31070c4d0>,).
# 2017-08-26 16:03:18,773 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2017-08-26 16:03:21,726 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-08-26 16:03:22,414 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-08-26 16:03:22,471 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x28f6ed7d0>,).
# 2017-08-26 16:03:22,977 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2017-08-26 16:04:00,603 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-08-26 16:04:00,821 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x16a048790>,).
# 2017-08-26 16:04:01,954 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-08-26 16:04:02,182 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x19087b0d0>,).
# 2017-08-26 16:04:02,183 - stpipe.SloperPipeline.dark_current - INFO - Step skipped.
# 2017-08-26 16:04:02,191 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-08-26 16:04:02,731 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-26 16:04:02,804 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x19087b0d0>,).
# 2017-08-26 16:04:02,932 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-08-26 16:04:02,933 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-08-26 16:04:02,934 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-08-26 16:04:02,935 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-08-26 16:04:02,936 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-08-26 16:04:02,938 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-08-26 16:04:04,448 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-08-26 16:04:06,561 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-08-26 16:04:07,299 - stpipe.SloperPipeline.persistence - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2017-08-26 16:04:07,300 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2017-08-26 16:04:07,301 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2017-08-26 16:04:07,369 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f20c110>,).
# 2017-08-26 16:04:09,612 - stpipe.SloperPipeline.persistence - WARNING - Missing reference file types:  PERSAT TRAPDENSITY TRAPPARS
# 2017-08-26 16:04:09,624 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-08-26 16:04:10,431 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:04:10,432 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:04:10,515 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f20c750>,).
# 2017-08-26 16:04:10,657 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-08-26 16:04:11,072 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:04:11,479 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:04:12,906 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-08-26 16:04:48,322 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-08-26 16:04:49,049 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:04:49,050 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:04:49,127 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111ce7d0>,).
# 2017-08-26 16:04:49,988 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:04:50,019 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:04:50,046 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-08-26 16:04:50,047 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-08-26 16:04:50,075 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-08-26 16:08:09,502 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-08-26 16:08:09,503 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-08-26 16:08:09,686 - stpipe.SloperPipeline.ramp_fit - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2017-08-26 16:08:09,837 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-08-26 16:08:09,838 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-08-26 16:08:09,846 - stpipe.SloperPipeline - INFO - Saving file MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2017-08-26 16:08:09,952 - stpipe.SloperPipeline - INFO - Step SloperPipeline done
# 2017-08-26 16:08:09,963 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-08-26 16:08:09,965 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-08-26 16:08:09,967 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-08-26 16:08:09,968 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-08-26 16:08:09,970 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-08-26 16:08:09,972 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-08-26 16:08:09,974 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-08-26 16:08:09,975 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-08-26 16:08:09,978 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-08-26 16:08:09,979 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-08-26 16:08:09,981 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-08-26 16:08:09,983 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-08-26 16:08:09,985 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-08-26 16:08:09,987 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-08-26 16:08:10,234 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('MRS_demo_data/det_image_seq2_MIRIFUSHORT_12SHORTexp1.fits',).
# 2017-08-26 16:08:10,235 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-08-26 16:08:13,411 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x16a07b850>,).
# 2017-08-26 16:08:13,538 - stpipe.SloperPipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2017-08-26 16:08:13,539 - stpipe.SloperPipeline.group_scale - WARNING - Step will be skipped
# 2017-08-26 16:08:13,546 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale done
# 2017-08-26 16:08:14,110 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-08-26 16:08:14,182 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x111ccc210>,).
# 2017-08-26 16:08:14,674 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2017-08-26 16:08:17,695 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-08-26 16:08:18,373 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-08-26 16:08:18,446 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111e8710>,).
# 2017-08-26 16:08:18,939 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2017-08-26 16:08:20,437 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-08-26 16:08:21,178 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-08-26 16:08:21,252 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10dab6610>,).
# 2017-08-26 16:08:21,758 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits
# 2017-08-26 16:08:25,604 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-08-26 16:08:26,317 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2017-08-26 16:08:26,395 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10da154d0>,).
# 2017-08-26 16:08:26,901 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2017-08-26 16:08:29,409 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-08-26 16:08:30,106 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-08-26 16:08:30,181 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x111212b10>,).
# 2017-08-26 16:08:30,689 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2017-08-26 16:09:05,214 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-08-26 16:09:05,431 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x16a0a6bd0>,).
# 2017-08-26 16:09:06,425 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-08-26 16:09:06,633 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111d9410>,).
# 2017-08-26 16:09:06,635 - stpipe.SloperPipeline.dark_current - INFO - Step skipped.
# 2017-08-26 16:09:06,642 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-08-26 16:09:07,196 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-26 16:09:07,269 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111d9410>,).
# 2017-08-26 16:09:07,397 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-08-26 16:09:07,398 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-08-26 16:09:07,399 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-08-26 16:09:07,400 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-08-26 16:09:07,401 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-08-26 16:09:07,403 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-08-26 16:09:08,827 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-08-26 16:09:10,679 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-08-26 16:09:11,397 - stpipe.SloperPipeline.persistence - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2017-08-26 16:09:11,399 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2017-08-26 16:09:11,399 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2017-08-26 16:09:11,475 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x110e60b50>,).
# 2017-08-26 16:09:13,579 - stpipe.SloperPipeline.persistence - WARNING - Missing reference file types:  PERSAT TRAPDENSITY TRAPPARS
# 2017-08-26 16:09:13,590 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-08-26 16:09:14,322 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:09:14,323 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:09:14,400 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111d9610>,).
# 2017-08-26 16:09:14,539 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-08-26 16:09:14,925 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:09:15,321 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:09:16,533 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-08-26 16:09:51,355 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-08-26 16:09:52,063 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:09:52,064 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:09:52,156 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10d7cc790>,).
# 2017-08-26 16:09:53,003 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:09:53,033 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:09:53,061 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-08-26 16:09:53,062 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-08-26 16:09:53,090 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-08-26 16:13:11,880 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-08-26 16:13:11,881 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-08-26 16:13:12,064 - stpipe.SloperPipeline.ramp_fit - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2017-08-26 16:13:12,192 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-08-26 16:13:12,193 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-08-26 16:13:12,200 - stpipe.SloperPipeline - INFO - Saving file MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2017-08-26 16:13:12,311 - stpipe.SloperPipeline - INFO - Step SloperPipeline done
# 2017-08-26 16:13:12,323 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-08-26 16:13:12,325 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-08-26 16:13:12,327 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-08-26 16:13:12,328 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-08-26 16:13:12,330 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-08-26 16:13:12,332 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-08-26 16:13:12,334 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-08-26 16:13:12,336 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-08-26 16:13:12,338 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-08-26 16:13:12,340 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-08-26 16:13:12,341 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-08-26 16:13:12,343 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-08-26 16:13:12,345 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-08-26 16:13:12,347 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-08-26 16:13:12,626 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('MRS_demo_data/det_image_seq3_MIRIFUSHORT_12SHORTexp1.fits',).
# 2017-08-26 16:13:12,627 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-08-26 16:13:15,880 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10da0ded0>,).
# 2017-08-26 16:13:16,011 - stpipe.SloperPipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2017-08-26 16:13:16,012 - stpipe.SloperPipeline.group_scale - WARNING - Step will be skipped
# 2017-08-26 16:13:16,019 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale done
# 2017-08-26 16:13:16,579 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-08-26 16:13:16,651 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x110cf8d50>,).
# 2017-08-26 16:13:17,142 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2017-08-26 16:13:20,144 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-08-26 16:13:20,853 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-08-26 16:13:20,928 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x111ccfc10>,).
# 2017-08-26 16:13:21,468 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2017-08-26 16:13:22,969 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-08-26 16:13:23,678 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-08-26 16:13:23,757 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x210012750>,).
# 2017-08-26 16:13:24,266 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits
# 2017-08-26 16:13:28,158 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-08-26 16:13:28,883 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2017-08-26 16:13:28,957 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f20c3d0>,).
# 2017-08-26 16:13:29,464 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2017-08-26 16:13:31,864 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-08-26 16:13:32,551 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-08-26 16:13:32,627 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x210012c10>,).
# 2017-08-26 16:13:33,128 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2017-08-26 16:14:07,686 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-08-26 16:14:07,897 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x110cf8d90>,).
# 2017-08-26 16:14:08,897 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-08-26 16:14:09,125 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10da0d750>,).
# 2017-08-26 16:14:09,126 - stpipe.SloperPipeline.dark_current - INFO - Step skipped.
# 2017-08-26 16:14:09,134 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-08-26 16:14:09,685 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-26 16:14:09,760 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x10da0d750>,).
# 2017-08-26 16:14:09,887 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-08-26 16:14:09,888 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-08-26 16:14:09,889 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-08-26 16:14:09,890 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-08-26 16:14:09,891 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-08-26 16:14:09,893 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-08-26 16:14:11,300 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-08-26 16:14:13,136 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-08-26 16:14:13,855 - stpipe.SloperPipeline.persistence - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2017-08-26 16:14:13,857 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2017-08-26 16:14:13,858 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2017-08-26 16:14:13,935 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111ce710>,).
# 2017-08-26 16:14:16,071 - stpipe.SloperPipeline.persistence - WARNING - Missing reference file types:  PERSAT TRAPDENSITY TRAPPARS
# 2017-08-26 16:14:16,083 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-08-26 16:14:16,844 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:14:16,846 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:14:16,923 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x20fff9a10>,).
# 2017-08-26 16:14:17,056 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-08-26 16:14:17,441 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:14:17,837 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:14:19,022 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-08-26 16:14:53,350 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-08-26 16:14:54,055 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:14:54,057 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:14:54,132 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x16a048790>,).
# 2017-08-26 16:14:55,014 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:14:55,044 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:14:55,070 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-08-26 16:14:55,071 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-08-26 16:14:55,101 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-08-26 16:16:50,577 - stpipe.SloperPipeline.ramp_fit - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/jwst-0.7.8rc2-py2.7-macosx-10.7-x86_64.egg/jwst/ramp_fitting/ramp_fit.py:1991: RuntimeWarning: invalid value encountered in sqrt
#   new_var = np.sqrt(poiss_2d + rn_2d**2.)
#
# 2017-08-26 16:18:14,657 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-08-26 16:18:14,658 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-08-26 16:18:14,831 - stpipe.SloperPipeline.ramp_fit - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2017-08-26 16:18:14,964 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-08-26 16:18:14,965 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-08-26 16:18:14,972 - stpipe.SloperPipeline - INFO - Saving file MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2017-08-26 16:18:15,074 - stpipe.SloperPipeline - INFO - Step SloperPipeline done
# 2017-08-26 16:18:15,085 - stpipe.SloperPipeline - INFO - SloperPipeline instance created.
# 2017-08-26 16:18:15,086 - stpipe.SloperPipeline.group_scale - INFO - GroupScaleStep instance created.
# 2017-08-26 16:18:15,088 - stpipe.SloperPipeline.saturation - INFO - SaturationStep instance created.
# 2017-08-26 16:18:15,090 - stpipe.SloperPipeline.rscd - INFO - RSCD_Step instance created.
# 2017-08-26 16:18:15,092 - stpipe.SloperPipeline.ipc - INFO - IPCStep instance created.
# 2017-08-26 16:18:15,094 - stpipe.SloperPipeline.ramp_fit - INFO - RampFitStep instance created.
# 2017-08-26 16:18:15,096 - stpipe.SloperPipeline.linearity - INFO - LinearityStep instance created.
# 2017-08-26 16:18:15,098 - stpipe.SloperPipeline.jump - INFO - JumpStep instance created.
# 2017-08-26 16:18:15,100 - stpipe.SloperPipeline.refpix - INFO - RefPixStep instance created.
# 2017-08-26 16:18:15,102 - stpipe.SloperPipeline.lastframe - INFO - LastFrameStep instance created.
# 2017-08-26 16:18:15,104 - stpipe.SloperPipeline.dq_init - INFO - DQInitStep instance created.
# 2017-08-26 16:18:15,106 - stpipe.SloperPipeline.dark_current - INFO - DarkCurrentStep instance created.
# 2017-08-26 16:18:15,109 - stpipe.SloperPipeline.persistence - INFO - PersistenceStep instance created.
# 2017-08-26 16:18:15,111 - stpipe.SloperPipeline.superbias - INFO - SuperBiasStep instance created.
# 2017-08-26 16:18:15,363 - stpipe.SloperPipeline - INFO - Step SloperPipeline running with args ('MRS_demo_data/det_image_seq4_MIRIFUSHORT_12SHORTexp1.fits',).
# 2017-08-26 16:18:15,365 - stpipe.SloperPipeline - INFO - Starting calwebb_sloper ...
# 2017-08-26 16:18:16,631 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x20fff9650>,).
# 2017-08-26 16:18:16,760 - stpipe.SloperPipeline.group_scale - WARNING - NFRAMES=1 is a power of 2
# 2017-08-26 16:18:16,761 - stpipe.SloperPipeline.group_scale - WARNING - Step will be skipped
# 2017-08-26 16:18:16,768 - stpipe.SloperPipeline.group_scale - INFO - Step group_scale done
# 2017-08-26 16:18:17,321 - stpipe.SloperPipeline.dq_init - INFO - Prefetch for MASK reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits'.
# 2017-08-26 16:18:17,393 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f20c3d0>,).
# 2017-08-26 16:18:17,895 - stpipe.SloperPipeline.dq_init - INFO - Using MASK reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_mask_0020.fits
# 2017-08-26 16:18:20,134 - stpipe.SloperPipeline.dq_init - INFO - Step dq_init done
# 2017-08-26 16:18:20,825 - stpipe.SloperPipeline.saturation - INFO - Prefetch for SATURATION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits'.
# 2017-08-26 16:18:20,899 - stpipe.SloperPipeline.saturation - INFO - Step saturation running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x111218950>,).
# 2017-08-26 16:18:21,407 - stpipe.SloperPipeline.saturation - INFO - Using SATURATION reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_saturation_0020.fits
# 2017-08-26 16:18:22,902 - stpipe.SloperPipeline.saturation - INFO - Step saturation done
# 2017-08-26 16:18:23,607 - stpipe.SloperPipeline.ipc - INFO - Prefetch for IPC reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits'.
# 2017-08-26 16:18:23,682 - stpipe.SloperPipeline.ipc - INFO - Step ipc running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x20fff9250>,).
# 2017-08-26 16:18:24,168 - stpipe.SloperPipeline.ipc - INFO - Using IPC reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_ipc_0008.fits
# 2017-08-26 16:18:28,055 - stpipe.SloperPipeline.ipc - INFO - Step ipc done
# 2017-08-26 16:18:28,791 - stpipe.SloperPipeline.linearity - INFO - Prefetch for LINEARITY reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits'.
# 2017-08-26 16:18:28,868 - stpipe.SloperPipeline.linearity - INFO - Step linearity running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x21009ffd0>,).
# 2017-08-26 16:18:29,384 - stpipe.SloperPipeline.linearity - INFO - Using Linearity reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_linearity_0023.fits
# 2017-08-26 16:18:31,769 - stpipe.SloperPipeline.linearity - INFO - Step linearity done
# 2017-08-26 16:18:32,463 - stpipe.SloperPipeline.rscd - INFO - Prefetch for RSCD reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits'.
# 2017-08-26 16:18:32,548 - stpipe.SloperPipeline.rscd - INFO - Step rscd running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x111ccc210>,).
# 2017-08-26 16:18:33,070 - stpipe.SloperPipeline.rscd - INFO - Using RSCD reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_rscd_0002.fits
# 2017-08-26 16:19:08,080 - stpipe.SloperPipeline.rscd - INFO - Step rscd done
# 2017-08-26 16:19:08,305 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x30f1edbd0>,).
# 2017-08-26 16:19:09,297 - stpipe.SloperPipeline.lastframe - INFO - Step lastframe done
# 2017-08-26 16:19:09,512 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x11101f210>,).
# 2017-08-26 16:19:09,513 - stpipe.SloperPipeline.dark_current - INFO - Step skipped.
# 2017-08-26 16:19:09,521 - stpipe.SloperPipeline.dark_current - INFO - Step dark_current done
# 2017-08-26 16:19:10,082 - stpipe.SloperPipeline.refpix - INFO - Prefetch for REFPIX reference file is 'N/A'.
# 2017-08-26 16:19:10,158 - stpipe.SloperPipeline.refpix - INFO - Step refpix running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x11101f210>,).
# 2017-08-26 16:19:10,288 - stpipe.SloperPipeline.refpix - INFO - use_side_ref_pixels = True
# 2017-08-26 16:19:10,289 - stpipe.SloperPipeline.refpix - INFO - odd_even_columns = True
# 2017-08-26 16:19:10,290 - stpipe.SloperPipeline.refpix - INFO - side_smoothing_length = 11
# 2017-08-26 16:19:10,291 - stpipe.SloperPipeline.refpix - INFO - side_gain = 1.000000
# 2017-08-26 16:19:10,292 - stpipe.SloperPipeline.refpix - INFO - odd_even_rows = True
# 2017-08-26 16:19:10,294 - stpipe.SloperPipeline.refpix - INFO - Subtracting initial read from each integration
# 2017-08-26 16:19:11,737 - stpipe.SloperPipeline.refpix - INFO - Adding initial read back in
# 2017-08-26 16:19:13,564 - stpipe.SloperPipeline.refpix - INFO - Step refpix done
# 2017-08-26 16:19:14,268 - stpipe.SloperPipeline.persistence - INFO - Prefetch for PERSAT reference file is 'N/A'.
# 2017-08-26 16:19:14,269 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPDENSITY reference file is 'N/A'.
# 2017-08-26 16:19:14,270 - stpipe.SloperPipeline.persistence - INFO - Prefetch for TRAPPARS reference file is 'N/A'.
# 2017-08-26 16:19:14,351 - stpipe.SloperPipeline.persistence - INFO - Step persistence running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x1111f7250>,).
# 2017-08-26 16:19:16,439 - stpipe.SloperPipeline.persistence - WARNING - Missing reference file types:  PERSAT TRAPDENSITY TRAPPARS
# 2017-08-26 16:19:16,451 - stpipe.SloperPipeline.persistence - INFO - Step persistence done
# 2017-08-26 16:19:17,180 - stpipe.SloperPipeline.jump - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:19:17,181 - stpipe.SloperPipeline.jump - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:19:17,259 - stpipe.SloperPipeline.jump - INFO - Step jump running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x2100123d0>,).
# 2017-08-26 16:19:17,390 - stpipe.SloperPipeline.jump - INFO - CR rejection threshold = 4 sigma
# 2017-08-26 16:19:17,776 - stpipe.SloperPipeline.jump - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:19:18,165 - stpipe.SloperPipeline.jump - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:19:19,345 - stpipe.SloperPipeline.jump - INFO - Executing two-point difference method
# 2017-08-26 16:19:53,752 - stpipe.SloperPipeline.jump - INFO - Step jump done
# 2017-08-26 16:19:54,501 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for GAIN reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits'.
# 2017-08-26 16:19:54,502 - stpipe.SloperPipeline.ramp_fit - INFO - Prefetch for READNOISE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits'.
# 2017-08-26 16:19:54,583 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit running with args (<jwst.datamodels.miri_ramp.MIRIRampModel object at 0x16a07b850>,).
# 2017-08-26 16:19:55,446 - stpipe.SloperPipeline.ramp_fit - INFO - Using READNOISE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_readnoise_0034.fits
# 2017-08-26 16:19:55,478 - stpipe.SloperPipeline.ramp_fit - INFO - Using GAIN reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_gain_0007.fits
# 2017-08-26 16:19:55,509 - stpipe.SloperPipeline.ramp_fit - INFO - Using algorithm = ols
# 2017-08-26 16:19:55,510 - stpipe.SloperPipeline.ramp_fit - INFO - Using weighting = optimal
# 2017-08-26 16:19:55,546 - stpipe.SloperPipeline.ramp_fit - INFO - Effective integration time per group: 2.77504
# 2017-08-26 16:23:14,409 - stpipe.SloperPipeline.ramp_fit - INFO - Number of groups per integration: 50
# 2017-08-26 16:23:14,411 - stpipe.SloperPipeline.ramp_fit - INFO - Number of integrations: 2
# 2017-08-26 16:23:14,588 - stpipe.SloperPipeline.ramp_fit - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rateints.fits
# 2017-08-26 16:23:14,723 - stpipe.SloperPipeline.ramp_fit - INFO - Step ramp_fit done
# 2017-08-26 16:23:14,724 - stpipe.SloperPipeline - INFO - ... ending calwebb_sloper
# 2017-08-26 16:23:14,732 - stpipe.SloperPipeline - INFO - Saving file MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits
# 2017-08-26 16:23:14,837 - stpipe.SloperPipeline - INFO - Step SloperPipeline done

# %% [markdown]
# #### Quick check of the pipeline steps applied in the output. We'll look at the first dither:

# %%
level2A_files = glob.glob(os.path.join(output_dir,'*_rate.fits'))

with datamodels.open(level2A_files[0]) as dm:
    # check the calibration step information
    print'Check step information status:'
    print 'dq_init: %s' % dm.meta.cal_step.dq_init
    print 'saturation: %s' % dm.meta.cal_step.saturation
    print 'linearity: %s' % dm.meta.cal_step.linearity
    print 'rscd: %s' % dm.meta.cal_step.rscd
    print 'lastframe: %s' % dm.meta.cal_step.lastframe
    print 'dark_current: %s' % dm.meta.cal_step.dark_sub
    print 'refpix: %s' % dm.meta.cal_step.refpix
    print 'jump: %s' % dm.meta.cal_step.jump
    print 'ramp_fit: %s' % dm.meta.cal_step.ramp_fit
# Out:
# Check step information status:
# dq_init: COMPLETE
# saturation: COMPLETE
# linearity: COMPLETE
# rscd: COMPLETE
# lastframe: COMPLETE
# dark_current: None
# refpix: COMPLETE
# jump: COMPLETE
# ramp_fit: COMPLETE

# %% [markdown]
# ### Level 2B pipeline

# %% [markdown]
# #### import the level 2B pipeline class and print description

# %%
from jwst.pipeline import Spec2Pipeline
print Spec2Pipeline.__doc__
# Out:
#     Spec2Pipeline: Processes JWST spectroscopic exposures from Level 2a to 2b.
#     Accepts a single exposure or an association as input.
#
#     Included steps are:
#     assign_wcs, background subtraction, NIRSpec MSA imprint subtraction,
#     NIRSpec MSA bad shutter flagging, 2-D subwindow extraction, flat field,
#     source type decision, straylight, fringe, pathloss, photom, resample_spec,
#     cube_build, and extract_1d.

# %% [markdown]
# For the MRS, the level 2B steps in order are: assign_wcs, bkg_subtract, flat_field, srctype, straylight, fringe, photom, cube_build, extract_1d
#
# Note that bkg_subtract requires an association so will not be applied to single files.

# %% [markdown]
# #### run pipeline
# We pass the level 2A files. The output level 2B files will be saved in the output_dir as '*_cal.fits'. A cube and 1D spectrum is also saved (see below).
#
# Note that since MIRISim does not add straylight, we can skip the straylight correction step.

# %%
for f in level2A_files:
    dm_2B = Spec2Pipeline.call(f, save_results=True, output_dir=output_dir, steps={'straylight':{'skip':True},
                                                                                       'cube_build':{'save_results':True},
                                                                                       'extract_1d':{'save_results':True}})
# Out:
# 2017-08-26 16:23:15,126 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-08-26 16:23:15,128 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-08-26 16:23:15,131 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-08-26 16:23:15,133 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2017-08-26 16:23:15,135 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-08-26 16:23:15,137 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-08-26 16:23:15,139 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-08-26 16:23:15,142 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-08-26 16:23:15,144 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-08-26 16:23:15,146 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-08-26 16:23:15,148 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-08-26 16:23:15,150 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-08-26 16:23:15,152 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-08-26 16:23:15,154 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-08-26 16:23:15,156 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-08-26 16:23:15,440 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2017-08-26 16:23:15,441 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-08-26 16:23:15,482 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:23:15,483 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2017-08-26 16:23:16,268 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-08-26 16:23:16,269 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-08-26 16:23:16,270 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-08-26 16:23:16,272 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2017-08-26 16:23:16,273 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-08-26 16:23:16,274 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-08-26 16:23:16,275 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-08-26 16:23:16,276 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-08-26 16:23:16,278 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-08-26 16:23:16,279 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-08-26 16:23:16,280 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-08-26 16:23:16,281 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-08-26 16:23:16,283 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2017-08-26 16:23:16,284 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2017-08-26 16:23:16,285 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-08-26 16:23:16,286 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2017-08-26 16:23:16,369 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x1111d9a50>,).
# 2017-08-26 16:23:22,017 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,019 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,021 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/constant' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,023 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/constant' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,029 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,030 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,033 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,035 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,040 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,042 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,055 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/remap_axes' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,056 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/remap_axes' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,058 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,059 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,069 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/scale' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:22,070 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/scale' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,342 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,343 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/compose' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,345 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,347 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/concatenate' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,350 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,351 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/shift' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,353 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,354 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/polynomial' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,360 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:262: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:24,361 - stpipe.Spec2Pipeline.assign_wcs - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/asdf/asdftypes.py:240: UserWarning: 'tag:stsci.edu:asdf/transform/identity' with version 1.0.0 found in file 'file:///Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf', but latest supported version is 1.1.0
#   warnings.warn(warning_string.format(fname))
#
# 2017-08-26 16:23:30,047 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-08-26 16:23:30,338 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-08-26 16:23:31,778 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-08-26 16:23:31,779 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-08-26 16:23:31,780 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2017-08-26 16:23:31,781 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-08-26 16:23:31,935 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x1185c0f90>,).
# 2017-08-26 16:23:33,353 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:23:34,148 - stpipe.Spec2Pipeline.flat_field - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/jwst-0.7.8rc2-py2.7-macosx-10.7-x86_64.egg/jwst/flatfield/flat_field.py:200: RuntimeWarning: divide by zero encountered in true_divide
#   science.data /= flat_data
#
# 2017-08-26 16:23:34,297 - stpipe.Spec2Pipeline.flat_field - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/jwst-0.7.8rc2-py2.7-macosx-10.7-x86_64.egg/jwst/flatfield/flat_field.py:201: RuntimeWarning: divide by zero encountered in true_divide
#   science.err /= flat_data
#
# 2017-08-26 16:23:34,886 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-08-26 16:23:35,067 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x1180d97d0>,).
# 2017-08-26 16:23:35,475 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2017-08-26 16:23:35,477 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of EXTENDED
# 2017-08-26 16:23:35,796 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-08-26 16:23:35,970 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.image.ImageModel object at 0x1128a9090>,).
# 2017-08-26 16:23:35,972 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2017-08-26 16:23:36,305 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2017-08-26 16:23:37,841 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2017-08-26 16:23:38,003 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.image.ImageModel object at 0x1128a9090>,).
# 2017-08-26 16:23:39,421 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2017-08-26 16:23:39,512 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:23:39,513 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:23:39,514 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:23:40,288 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2017-08-26 16:23:40,577 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2017-08-26 16:23:42,044 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-08-26 16:23:42,045 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2017-08-26 16:23:42,204 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x110d22150>,).
# 2017-08-26 16:23:43,525 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2017-08-26 16:23:44,442 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2017-08-26 16:23:44,443 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2017-08-26 16:23:44,444 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2017-08-26 16:23:44,445 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2017-08-26 16:23:44,446 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2017-08-26 16:23:44,681 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:23:45,798 - stpipe.Spec2Pipeline.photom - INFO - Writing PHOTMJSR with value: 42.5
# 2017-08-26 16:23:46,187 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2017-08-26 16:23:47,846 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:23:47,848 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:23:48,010 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.image.ImageModel object at 0x111a91290>,).
# 2017-08-26 16:23:48,011 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:23:48,012 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2017-08-26 16:23:48,014 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:23:48,014 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:23:48,015 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:23:49,566 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2017-08-26 16:23:49,568 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2017-08-26 16:23:49,569 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name
# 2017-08-26 16:23:49,570 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:23:49,622 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2017-08-26 16:23:49,624 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.002500
# 2017-08-26 16:23:49,625 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2017-08-26 16:23:50,529 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/gwcs/selector.py:433: RuntimeWarning: invalid value encountered in less_equal
#   temp = np.where(np.logical_or(temp <= val_range[0],
#
# 2017-08-26 16:23:50,531 - stpipe.Spec2Pipeline.cube_build - WARNING - /Users/patrickkavanagh/anaconda/envs/jwstb7.1rc2/lib/python2.7/site-packages/gwcs/selector.py:434: RuntimeWarning: invalid value encountered in greater_equal
#   temp >= val_range[1]),
#
# 2017-08-26 16:23:51,733 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2017-08-26 16:23:51,735 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:23:51,736 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  21.00  -0.00034857   0.13000000  -2.79499990   2.79499990
# 2017-08-26 16:23:51,738 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  20.00  -0.00019485   0.13000000  -2.66499990   2.66499990
# 2017-08-26 16:23:51,739 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1612   1.00   4.84728560   0.00250000   4.84728560   8.87728551
# 2017-08-26 16:23:51,740 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2017-08-26 16:23:51,741 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2017-08-26 16:23:55,652 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:24:25,488 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:24:55,161 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 59.5.s
# 2017-08-26 16:24:55,964 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 0.8.s
# 2017-08-26 16:24:55,965 - stpipe.Spec2Pipeline.cube_build - INFO - Time find Cube Flux= 0.8.s
# 2017-08-26 16:24:57,095 - stpipe.Spec2Pipeline.cube_build - INFO - Saving file MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2017-08-26 16:24:57,332 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2017-08-26 16:24:58,505 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-08-26 16:24:58,697 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x113a68fd0>,).
# 2017-08-26 16:24:59,508 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-08-26 16:24:59,623 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = extended
# 2017-08-26 16:25:01,885 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2017-08-26 16:25:02,140 - stpipe.Spec2Pipeline.extract_1d - INFO - Saving file MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2017-08-26 16:25:02,264 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-08-26 16:25:02,265 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:25:02,266 - stpipe.Spec2Pipeline - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq1_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2017-08-26 16:25:04,654 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2017-08-26 16:25:04,656 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2017-08-26 16:25:04,667 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-08-26 16:25:04,669 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-08-26 16:25:04,671 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-08-26 16:25:04,673 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2017-08-26 16:25:04,675 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-08-26 16:25:04,677 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-08-26 16:25:04,679 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-08-26 16:25:04,682 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-08-26 16:25:04,684 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-08-26 16:25:04,686 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-08-26 16:25:04,688 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-08-26 16:25:04,691 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-08-26 16:25:04,693 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-08-26 16:25:04,695 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-08-26 16:25:04,697 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-08-26 16:25:04,900 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2017-08-26 16:25:04,902 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-08-26 16:25:04,940 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:25:04,941 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2017-08-26 16:25:06,083 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-08-26 16:25:06,084 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-08-26 16:25:06,085 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-08-26 16:25:06,086 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2017-08-26 16:25:06,087 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-08-26 16:25:06,088 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-08-26 16:25:06,089 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-08-26 16:25:06,091 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-08-26 16:25:06,092 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-08-26 16:25:06,093 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-08-26 16:25:06,094 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-08-26 16:25:06,095 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-08-26 16:25:06,096 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2017-08-26 16:25:06,097 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2017-08-26 16:25:06,098 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-08-26 16:25:06,099 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2017-08-26 16:25:06,274 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x116097790>,).
# 2017-08-26 16:25:24,192 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-08-26 16:25:24,479 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-08-26 16:25:26,254 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-08-26 16:25:26,255 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-08-26 16:25:26,256 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2017-08-26 16:25:26,257 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-08-26 16:25:26,500 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x1182aea90>,).
# 2017-08-26 16:25:28,133 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:25:29,635 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-08-26 16:25:29,904 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x119341410>,).
# 2017-08-26 16:25:30,336 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2017-08-26 16:25:30,337 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of EXTENDED
# 2017-08-26 16:25:30,669 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-08-26 16:25:30,920 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.image.ImageModel object at 0x120164890>,).
# 2017-08-26 16:25:30,921 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2017-08-26 16:25:31,266 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2017-08-26 16:25:33,185 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2017-08-26 16:25:33,424 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.image.ImageModel object at 0x120164890>,).
# 2017-08-26 16:25:35,090 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2017-08-26 16:25:35,177 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:25:35,178 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:25:35,180 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:25:35,949 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2017-08-26 16:25:36,225 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2017-08-26 16:25:38,023 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-08-26 16:25:38,024 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2017-08-26 16:25:38,297 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x11d3198d0>,).
# 2017-08-26 16:25:39,877 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2017-08-26 16:25:41,055 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2017-08-26 16:25:41,057 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2017-08-26 16:25:41,058 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2017-08-26 16:25:41,059 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2017-08-26 16:25:41,060 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2017-08-26 16:25:41,160 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:25:42,287 - stpipe.Spec2Pipeline.photom - INFO - Writing PHOTMJSR with value: 42.5
# 2017-08-26 16:25:42,681 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2017-08-26 16:25:44,681 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:25:44,682 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:25:44,930 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.image.ImageModel object at 0x11be64fd0>,).
# 2017-08-26 16:25:44,931 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:25:44,932 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2017-08-26 16:25:44,933 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:25:44,934 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:25:44,935 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:25:46,708 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2017-08-26 16:25:46,710 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2017-08-26 16:25:46,711 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name
# 2017-08-26 16:25:46,712 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:25:46,772 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2017-08-26 16:25:46,773 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.002500
# 2017-08-26 16:25:46,774 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2017-08-26 16:25:48,840 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2017-08-26 16:25:48,841 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:25:48,842 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  21.00   0.00025316   0.13000000  -2.79499990   2.79499990
# 2017-08-26 16:25:48,844 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  20.00  -0.00001188   0.13000000  -2.66499990   2.66499990
# 2017-08-26 16:25:48,845 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1612   1.00   4.84728560   0.00250000   4.84728560   8.87728551
# 2017-08-26 16:25:48,847 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2017-08-26 16:25:48,848 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2017-08-26 16:25:52,686 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:26:22,872 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:26:52,596 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 59.9.s
# 2017-08-26 16:26:53,388 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 0.8.s
# 2017-08-26 16:26:53,389 - stpipe.Spec2Pipeline.cube_build - INFO - Time find Cube Flux= 0.8.s
# 2017-08-26 16:26:54,502 - stpipe.Spec2Pipeline.cube_build - INFO - Saving file MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2017-08-26 16:26:54,745 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2017-08-26 16:26:56,282 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-08-26 16:26:56,535 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x11d2a2290>,).
# 2017-08-26 16:26:57,569 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-08-26 16:26:57,695 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = extended
# 2017-08-26 16:26:59,986 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2017-08-26 16:27:00,246 - stpipe.Spec2Pipeline.extract_1d - INFO - Saving file MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2017-08-26 16:27:00,377 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-08-26 16:27:00,378 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:27:00,379 - stpipe.Spec2Pipeline - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq2_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2017-08-26 16:27:02,917 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2017-08-26 16:27:02,918 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2017-08-26 16:27:02,928 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-08-26 16:27:02,930 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-08-26 16:27:02,932 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-08-26 16:27:02,934 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2017-08-26 16:27:02,936 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-08-26 16:27:02,939 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-08-26 16:27:02,942 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-08-26 16:27:02,946 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-08-26 16:27:02,948 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-08-26 16:27:02,949 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-08-26 16:27:02,951 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-08-26 16:27:02,953 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-08-26 16:27:02,955 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-08-26 16:27:02,956 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-08-26 16:27:02,958 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-08-26 16:27:03,255 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2017-08-26 16:27:03,256 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-08-26 16:27:03,299 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:27:03,301 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2017-08-26 16:27:04,773 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-08-26 16:27:04,774 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-08-26 16:27:04,775 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-08-26 16:27:04,776 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2017-08-26 16:27:04,777 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-08-26 16:27:04,778 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-08-26 16:27:04,779 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-08-26 16:27:04,780 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-08-26 16:27:04,781 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-08-26 16:27:04,782 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-08-26 16:27:04,783 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-08-26 16:27:04,784 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-08-26 16:27:04,786 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2017-08-26 16:27:04,787 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2017-08-26 16:27:04,788 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-08-26 16:27:04,789 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2017-08-26 16:27:05,045 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x115b13850>,).
# 2017-08-26 16:27:26,869 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-08-26 16:27:27,161 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-08-26 16:27:29,282 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-08-26 16:27:29,284 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-08-26 16:27:29,285 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2017-08-26 16:27:29,287 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-08-26 16:27:29,613 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x1220e4450>,).
# 2017-08-26 16:27:31,550 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:27:33,073 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-08-26 16:27:33,434 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x126300410>,).
# 2017-08-26 16:27:33,840 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2017-08-26 16:27:33,841 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of EXTENDED
# 2017-08-26 16:27:34,172 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-08-26 16:27:34,521 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.image.ImageModel object at 0x1183a3190>,).
# 2017-08-26 16:27:34,523 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2017-08-26 16:27:34,865 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2017-08-26 16:27:37,086 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2017-08-26 16:27:37,404 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.image.ImageModel object at 0x1183a3190>,).
# 2017-08-26 16:27:39,355 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2017-08-26 16:27:39,452 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:27:39,454 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:27:39,455 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:27:40,263 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2017-08-26 16:27:40,544 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2017-08-26 16:27:42,706 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# ...
# 2017-08-26 16:28:28,774 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:28:58,396 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 59.6.s
# 2017-08-26 16:28:59,247 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 0.9.s
# 2017-08-26 16:28:59,249 - stpipe.Spec2Pipeline.cube_build - INFO - Time find Cube Flux= 0.9.s
# 2017-08-26 16:29:00,373 - stpipe.Spec2Pipeline.cube_build - INFO - Saving file MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2017-08-26 16:29:00,635 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2017-08-26 16:29:02,528 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-08-26 16:29:02,864 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x12591d450>,).
# 2017-08-26 16:29:04,134 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-08-26 16:29:04,277 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = extended
# 2017-08-26 16:29:06,543 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2017-08-26 16:29:06,834 - stpipe.Spec2Pipeline.extract_1d - INFO - Saving file MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2017-08-26 16:29:06,970 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-08-26 16:29:06,972 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:29:06,973 - stpipe.Spec2Pipeline - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq3_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2017-08-26 16:29:09,570 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2017-08-26 16:29:09,571 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done
# 2017-08-26 16:29:09,582 - stpipe.Spec2Pipeline - INFO - Spec2Pipeline instance created.
# 2017-08-26 16:29:09,583 - stpipe.Spec2Pipeline.pathloss - INFO - PathLossStep instance created.
# 2017-08-26 16:29:09,585 - stpipe.Spec2Pipeline.assign_wcs - INFO - AssignWcsStep instance created.
# 2017-08-26 16:29:09,587 - stpipe.Spec2Pipeline.msa_flagging - INFO - MSAFlagOpenStep instance created.
# 2017-08-26 16:29:09,589 - stpipe.Spec2Pipeline.imprint_subtract - INFO - ImprintStep instance created.
# 2017-08-26 16:29:09,591 - stpipe.Spec2Pipeline.photom - INFO - PhotomStep instance created.
# 2017-08-26 16:29:09,593 - stpipe.Spec2Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-08-26 16:29:09,596 - stpipe.Spec2Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-08-26 16:29:09,598 - stpipe.Spec2Pipeline.straylight - INFO - StraylightStep instance created.
# 2017-08-26 16:29:09,600 - stpipe.Spec2Pipeline.bkg_subtract - INFO - BackgroundStep instance created.
# 2017-08-26 16:29:09,602 - stpipe.Spec2Pipeline.extract_2d - INFO - Extract2dStep instance created.
# 2017-08-26 16:29:09,603 - stpipe.Spec2Pipeline.fringe - INFO - FringeStep instance created.
# 2017-08-26 16:29:09,606 - stpipe.Spec2Pipeline.flat_field - INFO - FlatFieldStep instance created.
# 2017-08-26 16:29:09,608 - stpipe.Spec2Pipeline.srctype - INFO - SourceTypeStep instance created.
# 2017-08-26 16:29:09,610 - stpipe.Spec2Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-08-26 16:29:09,979 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline running with args ('MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits',).
# 2017-08-26 16:29:09,980 - stpipe.Spec2Pipeline - INFO - Starting calwebb_spec2 ...
# 2017-08-26 16:29:10,007 - stpipe.Spec2Pipeline - INFO - Processing product MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:29:10,008 - stpipe.Spec2Pipeline - INFO - Working on input MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_rate.fits ...
# 2017-08-26 16:29:11,809 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for CAMERA reference file is 'N/A'.
# 2017-08-26 16:29:11,810 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for COLLIMATOR reference file is 'N/A'.
# 2017-08-26 16:29:11,811 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISPERSER reference file is 'N/A'.
# 2017-08-26 16:29:11,812 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for DISTORTION reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_distortion_0021.asdf'.
# 2017-08-26 16:29:11,813 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FILTEROFFSET reference file is 'N/A'.
# 2017-08-26 16:29:11,814 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FORE reference file is 'N/A'.
# 2017-08-26 16:29:11,816 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for FPA reference file is 'N/A'.
# 2017-08-26 16:29:11,817 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUFORE reference file is 'N/A'.
# 2017-08-26 16:29:11,818 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUPOST reference file is 'N/A'.
# 2017-08-26 16:29:11,819 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for IFUSLICER reference file is 'N/A'.
# 2017-08-26 16:29:11,820 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for MSA reference file is 'N/A'.
# 2017-08-26 16:29:11,821 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for OTE reference file is 'N/A'.
# 2017-08-26 16:29:11,822 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for REGIONS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_regions_0016.asdf'.
# 2017-08-26 16:29:11,823 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for SPECWCS reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_specwcs_0015.asdf'.
# 2017-08-26 16:29:11,824 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for V2V3 reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_v2v3_0009.asdf'.
# 2017-08-26 16:29:11,825 - stpipe.Spec2Pipeline.assign_wcs - INFO - Prefetch for WAVELENGTHRANGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_wavelengthrange_0003.asdf'.
# 2017-08-26 16:29:12,164 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs running with args (<jwst.datamodels.image.ImageModel object at 0x119921350>,).
# 2017-08-26 16:29:38,165 - stpipe.Spec2Pipeline.assign_wcs - INFO - COMPLETED assign_wcs
# 2017-08-26 16:29:38,452 - stpipe.Spec2Pipeline.assign_wcs - INFO - Step assign_wcs done
# 2017-08-26 16:29:40,864 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for DFLAT reference file is 'N/A'.
# 2017-08-26 16:29:40,865 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FFLAT reference file is 'N/A'.
# 2017-08-26 16:29:40,866 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for FLAT reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_flat_0248.fits'.
# 2017-08-26 16:29:40,867 - stpipe.Spec2Pipeline.flat_field - INFO - Prefetch for SFLAT reference file is 'N/A'.
# 2017-08-26 16:29:41,270 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field running with args (<jwst.datamodels.image.ImageModel object at 0x1287c2c10>,).
# 2017-08-26 16:29:43,466 - stpipe.Spec2Pipeline.flat_field - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:29:45,015 - stpipe.Spec2Pipeline.flat_field - INFO - Step flat_field done
# 2017-08-26 16:29:45,436 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype running with args (<jwst.datamodels.image.ImageModel object at 0x12b73e590>,).
# 2017-08-26 16:29:45,849 - stpipe.Spec2Pipeline.srctype - INFO - Input EXP_TYPE is MIR_MRS
# 2017-08-26 16:29:45,850 - stpipe.Spec2Pipeline.srctype - INFO - Input SRCTYPE is unknown. Setting to default value of EXTENDED
# 2017-08-26 16:29:46,179 - stpipe.Spec2Pipeline.srctype - INFO - Step srctype done
# 2017-08-26 16:29:46,609 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight running with args (<jwst.datamodels.image.ImageModel object at 0x12ba0bd90>,).
# 2017-08-26 16:29:46,611 - stpipe.Spec2Pipeline.straylight - INFO - Step skipped.
# 2017-08-26 16:29:46,953 - stpipe.Spec2Pipeline.straylight - INFO - Step straylight done
# 2017-08-26 16:29:49,507 - stpipe.Spec2Pipeline.fringe - INFO - Prefetch for FRINGE reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits'.
# 2017-08-26 16:29:49,904 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe running with args (<jwst.datamodels.image.ImageModel object at 0x12ba0bd90>,).
# 2017-08-26 16:29:52,070 - stpipe.Spec2Pipeline.fringe - INFO - Using FRINGE reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_fringe_0031.fits
# 2017-08-26 16:29:52,183 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_PARTIAL_DATA does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:29:52,185 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:29:52,186 - stpipe.Spec2Pipeline.fringe - WARNING - Keyword CDP_UNRELIABLE_ERROR does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:29:53,004 - stpipe.Spec2Pipeline.fringe - INFO - The DQ values in the reference file will NOT be used to update the    DQ values in the output DQ array.
# 2017-08-26 16:29:53,289 - stpipe.Spec2Pipeline.fringe - INFO - Step fringe done
# 2017-08-26 16:29:55,754 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for AREA reference file is 'N/A'.
# 2017-08-26 16:29:55,755 - stpipe.Spec2Pipeline.photom - INFO - Prefetch for PHOTOM reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits'.
# 2017-08-26 16:29:56,164 - stpipe.Spec2Pipeline.photom - INFO - Step photom running with args (<jwst.datamodels.image.ImageModel object at 0x1286f7710>,).
# 2017-08-26 16:29:58,230 - stpipe.Spec2Pipeline.photom - INFO - Using photom reference file: /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_photom_0020.fits
# 2017-08-26 16:29:59,893 - stpipe.Spec2Pipeline.photom - INFO - Using area reference file: N/A
# 2017-08-26 16:29:59,895 - stpipe.Spec2Pipeline.photom - INFO - Using instrument: MIRI
# 2017-08-26 16:29:59,896 - stpipe.Spec2Pipeline.photom - INFO -  detector: MIRIFUSHORT
# 2017-08-26 16:29:59,897 - stpipe.Spec2Pipeline.photom - INFO -  exp_type: MIR_MRS
# 2017-08-26 16:29:59,898 - stpipe.Spec2Pipeline.photom - INFO -  band: SHORT
# 2017-08-26 16:30:00,037 - stpipe.Spec2Pipeline.photom - WARNING - Keyword CDP_LOW_QUAL does not correspond to an existing DQ mnemonic, so will be ignored
# 2017-08-26 16:30:01,163 - stpipe.Spec2Pipeline.photom - INFO - Writing PHOTMJSR with value: 42.5
# 2017-08-26 16:30:01,555 - stpipe.Spec2Pipeline.photom - INFO - Step photom done
# 2017-08-26 16:30:04,219 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:30:04,221 - stpipe.Spec2Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:30:04,621 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.image.ImageModel object at 0x129f8c850>,).
# 2017-08-26 16:30:04,622 - stpipe.Spec2Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:30:04,624 - stpipe.Spec2Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2017-08-26 16:30:04,625 - stpipe.Spec2Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:30:04,626 - stpipe.Spec2Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:30:04,627 - stpipe.Spec2Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:30:06,912 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2017-08-26 16:30:06,913 - stpipe.Spec2Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2017-08-26 16:30:06,914 - stpipe.Spec2Pipeline.cube_build - INFO - Output Name
# 2017-08-26 16:30:06,916 - stpipe.Spec2Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:30:07,010 - stpipe.Spec2Pipeline.cube_build - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2017-08-26 16:30:07,011 - stpipe.Spec2Pipeline.cube_build - INFO - Region of interest  0.150000 0.002500
# 2017-08-26 16:30:07,012 - stpipe.Spec2Pipeline.cube_build - INFO - Number of bands in cube  2
# 2017-08-26 16:30:09,091 - stpipe.Spec2Pipeline.cube_build - INFO - Cube Geometry:
# 2017-08-26 16:30:09,092 - stpipe.Spec2Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:30:09,093 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 1    42  21.00  -0.00031821   0.13000000  -2.79499990   2.79499990
# 2017-08-26 16:30:09,095 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 2    40  20.00  -0.00017473   0.13000000  -2.66499990   2.66499990
# 2017-08-26 16:30:09,096 - stpipe.Spec2Pipeline.cube_build - INFO - Axis 3  1612   1.00   4.84728560   0.00250000   4.84728560   8.87728551
# 2017-08-26 16:30:09,098 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2017-08-26 16:30:09,099 - stpipe.Spec2Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2017-08-26 16:30:13,589 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:30:43,515 - stpipe.Spec2Pipeline.cube_build - INFO - Number of files/models in band 1
# 2017-08-26 16:31:13,340 - stpipe.Spec2Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 59.8.s
# 2017-08-26 16:31:14,141 - stpipe.Spec2Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 0.8.s
# 2017-08-26 16:31:14,143 - stpipe.Spec2Pipeline.cube_build - INFO - Time find Cube Flux= 0.8.s
# 2017-08-26 16:31:15,279 - stpipe.Spec2Pipeline.cube_build - INFO - Saving file MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_s3d.fits
# 2017-08-26 16:31:15,561 - stpipe.Spec2Pipeline.cube_build - INFO - Step cube_build done
# 2017-08-26 16:31:17,795 - stpipe.Spec2Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-08-26 16:31:18,251 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x11c79fa90>,).
# 2017-08-26 16:31:19,796 - stpipe.Spec2Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-08-26 16:31:19,958 - stpipe.Spec2Pipeline.extract_1d - INFO - source_type = extended
# 2017-08-26 16:31:22,235 - stpipe.Spec2Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2017-08-26 16:31:22,559 - stpipe.Spec2Pipeline.extract_1d - INFO - Saving file MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_x1d.fits
# 2017-08-26 16:31:22,722 - stpipe.Spec2Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-08-26 16:31:22,723 - stpipe.Spec2Pipeline - INFO - Finished processing product MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1
# 2017-08-26 16:31:22,724 - stpipe.Spec2Pipeline - INFO - Step.save_model MRS_demo_data_pipelined/det_image_seq4_MIRIFUSHORT_12SHORTexp1_cal.fits
# 2017-08-26 16:31:25,441 - stpipe.Spec2Pipeline - INFO - Ending calwebb_spec2
# 2017-08-26 16:31:25,443 - stpipe.Spec2Pipeline - INFO - Step Spec2Pipeline done

# %% [markdown]
# ### check of output
#
# The level 2B pipeline for the MRS produces three files for each input:
#
# _cal.fits - the calibrated level 2B file
#
# _s3d.fits - the cube
#
# _x1d.fits - the 1d spectrum
#
# We can have a look at each of these for the first dither

# %%
# set the output file names
level2B_files = glob.glob(os.path.join(output_dir,'*_cal.fits'))
cube_files = glob.glob(os.path.join(output_dir,'*_s3d.fits'))
spec_files = glob.glob(os.path.join(output_dir,'*_x1d.fits'))

# %% [markdown]
# #### level 2B file

# %%
with datamodels.open(level2B_files[0]) as dm:
    # check the calibration step information
    print'Check step information status:'
    print 'assign_wcs: %s' % dm.meta.cal_step.assign_wcs
    print 'flat_field: %s' % dm.meta.cal_step.flat_field
    print 'srctype: %s' % dm.meta.cal_step.srctype
    print 'fringe: %s' % dm.meta.cal_step.fringe
    print 'photom: %s' % dm.meta.cal_step.photom
# Out:
# Check step information status:
# assign_wcs: COMPLETE
# flat_field: COMPLETE
# srctype: COMPLETE
# fringe: COMPLETE
# photom: COMPLETE

# %% [markdown]
# #### Look at level 1B and calibrated level 2B image. We'll look at the first dither only

# %%
# open the input image as a jwst data model
with datamodels.open(input_files[0]) as in_dm:
    with datamodels.open(level2B_files[0]) as out_dm:
        
        # plot--------------------------------------
        # show the input ramp image and the calibrated
        # slope image. Note the user may have to adjust
        # the scale parameters
        fig, axs = plt.subplots(1, 2, figsize=(12, 6))

        # sum the groups in the first integration of the input ramp image and plot
        axs[0].imshow(in_dm.data[0,-1,:,:], cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=9e3,vmax=2e4))
        axs[0].annotate('Input ramp image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[0].set_facecolor('black')
        axs[1].imshow(out_dm.data, cmap='jet', interpolation='nearest', origin='lower', vmin=0, vmax=200)
        axs[1].annotate('Calibrated slope image', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
        axs[1].set_facecolor('black')

        plt.tight_layout()
        plt.show()

# %% [markdown]
# #### Look at cube file. We'll look at the first dither only

# %%
# open the cube as a jwst data model
cube_dm = datamodels.open(cube_files[0])
    
# plot--------------------------------------
# sum some of the the frames in each channel
# Note the user may have to adjust the scaling
# parameters
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=100,vmax=5e4))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(cube_dm.data[1200:1400], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=400,vmax=5e4))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### 1D spectrum

# %%
from jwst.datamodels import SpecModel

# open the spectrum as a jwst data model
with SpecModel(spec_files[0]) as spec_dm:
    # plot--------------------------------------
    # simple XY plot of the spectrum
    fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

    # plot the spectrum in the channel 2 wavelength range
    spaxel_area = cube_dm.meta.wcsinfo.cdelt1 * cube_dm.meta.wcsinfo.cdelt2 * 3600**2
    axs[0].plot(spec_dm.spec_table['WAVELENGTH'], spec_dm.spec_table['FLUX'] * spaxel_area, c='b', marker='.', markersize=3, linestyle='-', linewidth=2)
    axs[0].set_ylabel(r'Flux (mJy)')
    axs[0].set_xlabel(r'Wavelength ($\mu$m)')
    axs[0].set_xlim(4.9,5.7)
    #axs[0].set_ylim(0,6000)
    axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')

    
    axs[1].plot(spec_dm.spec_table['WAVELENGTH'], spec_dm.spec_table['FLUX'] * spaxel_area, c='b', marker='.', markersize=3, linestyle='-', linewidth=2)
    axs[1].set_xlabel(r'Wavelength (mJy)')
    axs[1].set_xlim(7.5,8.7)
    axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')


    plt.show()

# %% [markdown]
# ### Level 3 pipeline
#
# We first create an association file in the output directory containing the list of level 2B files ('_cal.fits') produced by the level 2B pipeline. We can then combine the dithers with the Spec3Pipeline.
#
# A combined cube and 1D spectrum is saved (see below).

# %% [markdown]
# #### import the level 3 pipeline class and print description

# %%
from jwst.pipeline import Spec3Pipeline
print Spec3Pipeline.__doc__
# Out:
#     Spec3Pipeline: Processes JWST spectroscopic exposures from Level 2b to 3.
#
#     Included steps are:
#     MIRI MRS background matching (skymatch)
#     outlier detection (outlier_detection)
#     2-D spectroscopic resampling (resample_spec)
#     3-D spectroscopic resampling (cube_build)
#     1-D spectral extraction (extract_1d)

# %% [markdown]
# For the MRS, the level 3 steps in order are: mrs_imatch, outlier_detection, cube_build, extract_1d
#
# Note that there is currently a problem with the outlier detection step so we will skip it in the call to the Spec3Pipeline.

# %% [markdown]
# #### create the level 3 association using the asn_from_list tool

# %%
call(["asn_from_list", "-o", "MRS_asn.json"] + level2B_files + ["--product-name", "dither"])
# Out:
# 0

# %% [markdown]
# #### run pipeline

# %%
dm_3_container = datamodels.ModelContainer("MRS_asn.json")

Spec3Pipeline.call(dm_3_container, save_results=True, output_dir=output_dir, steps={'outlier_detection':{'skip':True},
                                                                                    'cube_build':{'save_results':True},
                                                                                    'extract_1d':{'save_results':True}})

# move the association file to output_dir
shutil.move('MRS_asn.json',os.path.join(output_dir,'MRS_asn.json'))
# Out:
# 2017-08-26 16:31:45,650 - stpipe.Spec3Pipeline - INFO - Spec3Pipeline instance created.
# 2017-08-26 16:31:45,653 - stpipe.Spec3Pipeline.resample_spec - INFO - ResampleSpecStep instance created.
# 2017-08-26 16:31:45,655 - stpipe.Spec3Pipeline.mrs_imatch - INFO - MRSIMatchStep instance created.
# 2017-08-26 16:31:45,658 - stpipe.Spec3Pipeline.cube_build - INFO - CubeBuildStep instance created.
# 2017-08-26 16:31:45,661 - stpipe.Spec3Pipeline.outlier_detection - INFO - OutlierDetectionStep instance created.
# 2017-08-26 16:31:45,664 - stpipe.Spec3Pipeline.extract_1d - INFO - Extract1dStep instance created.
# 2017-08-26 16:31:46,364 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline running with args (<jwst.datamodels.container.ModelContainer object at 0x11ea5d0d0>,).
# 2017-08-26 16:31:46,366 - stpipe.Spec3Pipeline - INFO - Starting calwebb_spec3 ...
# 2017-08-26 16:31:53,666 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch running with args (<jwst.datamodels.container.ModelContainer object at 0x10d71af90>,).
# 2017-08-26 16:32:14,782 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2017-08-26 16:32:14,783 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:32:14,784 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2017-08-26 16:32:14,785 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:32:14,786 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:32:14,788 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:32:14,789 - stpipe.CubeBuildStep - INFO -  Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2017-08-26 16:32:19,179 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes covers the MIRI Channels: ['1']
# 2017-08-26 16:32:19,180 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2017-08-26 16:32:19,182 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:32:19,358 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2017-08-26 16:32:19,359 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Region of interest  0.150000 0.002500
# 2017-08-26 16:32:19,360 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of bands in cube  1
# 2017-08-26 16:32:22,997 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2017-08-26 16:32:22,999 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:32:23,000 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    52  26.00  -0.00001638   0.13000000  -3.44499987   3.44499987
# 2017-08-26 16:32:23,001 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    38  19.00  -0.00000771   0.13000000  -2.53499991   2.53499991
# 2017-08-26 16:32:23,003 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3   372   1.00   4.84711374   0.00250000   4.84711374   5.77711372
# 2017-08-26 16:32:23,004 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 1 SHORT
# 2017-08-26 16:32:54,600 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.2.s
# 2017-08-26 16:32:55,608 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 32.4.s
# 2017-08-26 16:33:27,091 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.2.s
# 2017-08-26 16:33:28,115 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 32.5.s
# 2017-08-26 16:33:59,695 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.2.s
# 2017-08-26 16:34:00,714 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 32.5.s
# 2017-08-26 16:34:33,129 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.2.s
# 2017-08-26 16:34:34,140 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 33.4.s
# 2017-08-26 16:34:34,191 - stpipe.CubeBuildStep - INFO - Number of IFUCube models returned from building single IFUCubes 4
# 2017-08-26 16:34:40,579 - stpipe.CubeBuildStep - INFO - CubeBuildStep instance created.
# 2017-08-26 16:34:40,580 - stpipe.CubeBuildStep - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:34:40,581 - stpipe.CubeBuildStep - INFO - Input interpolation: pointcloud
# 2017-08-26 16:34:40,582 - stpipe.CubeBuildStep - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:34:40,583 - stpipe.CubeBuildStep - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:34:40,584 - stpipe.CubeBuildStep - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:34:40,586 - stpipe.CubeBuildStep - INFO -  Single = true, creating a set of single exposures mapped to output IFUCube coordinate system
# 2017-08-26 16:34:45,375 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes covers the MIRI Channels: ['2']
# 2017-08-26 16:34:45,376 - stpipe.Spec3Pipeline.mrs_imatch - INFO - The desired cubes covers the MIRI subchannels: ['SHORT']
# 2017-08-26 16:34:45,377 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:34:45,557 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Increasing spatial region of interest default value set for 4 dithers 0.150000
# 2017-08-26 16:34:45,558 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Region of interest  0.150000 0.004000
# 2017-08-26 16:34:45,559 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Number of bands in cube  1
# 2017-08-26 16:34:49,443 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube Geometry:
# 2017-08-26 16:34:49,444 - stpipe.Spec3Pipeline.mrs_imatch - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:34:49,445 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 1    60  30.00  -0.00003261   0.13000000  -3.96499985   3.96499985
# 2017-08-26 16:34:49,447 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 2    46  23.00  -0.00009315   0.13000000  -3.05499989   3.05499989
# 2017-08-26 16:34:49,449 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Axis 3   358   1.00   7.44517473   0.00400000   7.44517473   8.87717480
# 2017-08-26 16:34:49,450 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Cube covers channel, subchannel: 2 SHORT
# 2017-08-26 16:35:22,862 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.3.s
# 2017-08-26 16:35:24,009 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 34.4.s
# 2017-08-26 16:35:57,987 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.3.s
# 2017-08-26 16:35:59,137 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 35.1.s
# 2017-08-26 16:36:31,992 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.3.s
# 2017-08-26 16:36:33,114 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 33.9.s
# 2017-08-26 16:37:06,333 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time to interpolate at spaxel values = 0.3.s
# 2017-08-26 16:37:07,457 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Time Create Single IFUcube  = 34.3.s
# 2017-08-26 16:37:07,518 - stpipe.CubeBuildStep - INFO - Number of IFUCube models returned from building single IFUCubes 4
# 2017-08-26 16:37:19,030 - stpipe.Spec3Pipeline.mrs_imatch - INFO - Step mrs_imatch done
# 2017-08-26 16:37:19,900 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection running with args (<jwst.datamodels.container.ModelContainer object at 0x10d71af90>,).
# 2017-08-26 16:37:19,902 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step skipped.
# 2017-08-26 16:37:19,905 - stpipe.Spec3Pipeline.outlier_detection - INFO - Step outlier_detection done
# 2017-08-26 16:37:24,023 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:37:24,024 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:37:26,241 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:37:26,242 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:37:28,435 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:37:28,436 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:37:30,628 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for CUBEPAR reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits'.
# 2017-08-26 16:37:30,629 - stpipe.Spec3Pipeline.cube_build - INFO - Prefetch for RESOL reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_resol_0003.fits'.
# 2017-08-26 16:37:31,442 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build running with args (<jwst.datamodels.container.ModelContainer object at 0x10d71af90>,).
# 2017-08-26 16:37:31,444 - stpipe.Spec3Pipeline.cube_build - INFO - Starting IFU Cube Building Step
# 2017-08-26 16:37:31,445 - stpipe.Spec3Pipeline.cube_build - INFO - Input interpolation: pointcloud
# 2017-08-26 16:37:31,446 - stpipe.Spec3Pipeline.cube_build - INFO - Coordinate system to use: ra-dec
# 2017-08-26 16:37:31,447 - stpipe.Spec3Pipeline.cube_build - INFO - Weighting method for point cloud: msm
# 2017-08-26 16:37:31,448 - stpipe.Spec3Pipeline.cube_build - INFO - Power Weighting distance : 2.000000
# 2017-08-26 16:37:36,889 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes covers the MIRI Channels: ['1', '2']
# 2017-08-26 16:37:36,890 - stpipe.Spec3Pipeline.cube_build - INFO - The desired cubes covers the MIRI subchannels: ['SHORT', 'SHORT']
# 2017-08-26 16:37:36,891 - stpipe.Spec3Pipeline.cube_build - INFO - Output Name dither_ch1-2-short_s3d.fits
# 2017-08-26 16:37:36,892 - stpipe.Spec3Pipeline.cube_build - INFO - Reading  cube parameter file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_cubepar_0001.fits
# 2017-08-26 16:37:37,071 - stpipe.Spec3Pipeline.cube_build - INFO - Region of interest  0.100000 0.002500
# 2017-08-26 16:37:37,072 - stpipe.Spec3Pipeline.cube_build - INFO - Number of bands in cube  2
# 2017-08-26 16:37:45,319 - stpipe.Spec3Pipeline.cube_build - INFO - Cube Geometry:
# 2017-08-26 16:37:45,320 - stpipe.Spec3Pipeline.cube_build - INFO - axis# Naxis  CRPIX    CRVAL      CDELT(arc sec)  MIN & Max (xi,eta arc sec)
# 2017-08-26 16:37:45,322 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 1    60  30.00  -0.00003261   0.13000000  -3.96499985   3.96499985
# 2017-08-26 16:37:45,323 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 2    46  23.00  -0.00009315   0.13000000  -3.05499989   3.05499989
# 2017-08-26 16:37:45,324 - stpipe.Spec3Pipeline.cube_build - INFO - Axis 3  1612   1.00   4.84728560   0.00250000   4.84728560   8.87728551
# 2017-08-26 16:37:45,326 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 1 SHORT
# 2017-08-26 16:37:45,327 - stpipe.Spec3Pipeline.cube_build - INFO - Cube covers channel, subchannel: 2 SHORT
# 2017-08-26 16:37:52,281 - stpipe.Spec3Pipeline.cube_build - INFO - Number of files/models in band 4
# 2017-08-26 16:39:23,886 - stpipe.Spec3Pipeline.cube_build - INFO - Number of files/models in band 4
# 2017-08-26 16:40:55,128 - stpipe.Spec3Pipeline.cube_build - INFO - Time Map All slices on Detector to Cube = 182.8.s
# 2017-08-26 16:40:56,413 - stpipe.Spec3Pipeline.cube_build - INFO - Time to interpolate at spaxel values = 1.3.s
# 2017-08-26 16:40:56,414 - stpipe.Spec3Pipeline.cube_build - INFO - Time find Cube Flux= 1.3.s
# 2017-08-26 16:40:58,234 - stpipe.Spec3Pipeline.cube_build - INFO - Saving file MRS_demo_data_pipelined/dither_ch1-2-short_s3d.fits
# 2017-08-26 16:40:58,689 - stpipe.Spec3Pipeline.cube_build - INFO - Step cube_build done
# 2017-08-26 16:41:02,676 - stpipe.Spec3Pipeline.extract_1d - INFO - Prefetch for EXTRACT1D reference file is '/Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json'.
# 2017-08-26 16:41:03,531 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d running with args (<jwst.datamodels.ifucube.IFUCubeModel object at 0x18ac4a7d0>,).
# 2017-08-26 16:41:06,490 - stpipe.Spec3Pipeline.extract_1d - INFO - Using EXTRACT1D reference file /Users/patrickkavanagh/crds_mirror/references/jwst/miri/jwst_miri_extract1d_0003.json
# 2017-08-26 16:41:06,750 - stpipe.Spec3Pipeline.extract_1d - INFO - source_type = extended
# 2017-08-26 16:41:09,167 - stpipe.Spec3Pipeline.extract_1d - INFO - Data have been flux calibrated; setting net to 0.
# 2017-08-26 16:41:09,683 - stpipe.Spec3Pipeline.extract_1d - INFO - Saving file MRS_demo_data_pipelined/dither_extract_1d.fits
# 2017-08-26 16:41:09,939 - stpipe.Spec3Pipeline.extract_1d - INFO - Step extract_1d done
# 2017-08-26 16:41:09,940 - stpipe.Spec3Pipeline - INFO - Ending calwebb_spec3
# 2017-08-26 16:41:09,941 - stpipe.Spec3Pipeline - INFO - Step Spec3Pipeline done

# %% [markdown]
# #### plot the cube

# %%
cube_file = glob.glob(os.path.join(output_dir,"dither*s3d.fits"))[0]
cube_dm = datamodels.open(cube_file)
fig, axs = plt.subplots(1, 2, figsize=(12, 6))

axs[0].imshow(np.sum(cube_dm.data[100:300], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=100,vmax=5e4))
axs[0].annotate('Collapsed cube: short channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[0].set_facecolor('black')
axs[1].imshow(np.sum(cube_dm.data[1200:1400], axis=0), cmap='jet', interpolation='nearest', origin='lower', norm=LogNorm(vmin=400,vmax=5e4))
axs[1].annotate('Collapsed cube: long channel', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')
axs[1].set_facecolor('black')

plt.tight_layout()
plt.show()

# %% [markdown]
# #### plot the spectrum

# %%
spec_file = glob.glob(os.path.join(output_dir,"dither_extract_1d.fits"))[0]
dm = datamodels.open(spec_file)

fig, axs = plt.subplots(1, 2, figsize=(12, 6), sharey=True)

# plot the spectrum in the channel 2 wavelength range
spaxel_area = cube_dm.meta.wcsinfo.cdelt1 * cube_dm.meta.wcsinfo.cdelt2 * 3600**2
axs[0].plot(dm.spec[0].spec_table['WAVELENGTH'], dm.spec[0].spec_table['FLUX'] * spaxel_area, c='b', marker='.', markersize=3, linestyle='-', linewidth=2)
axs[0].set_ylabel(r'Flux ($\mu$Jy)')
axs[0].set_xlabel(r'Wavelength ($\mu$m)')
axs[0].set_xlim(4.9,5.7)
#axs[0].set_ylim(0,6000)
axs[0].annotate('Channel 1', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')


axs[1].plot(dm.spec[0].spec_table['WAVELENGTH'], dm.spec[0].spec_table['FLUX'] * spaxel_area, c='b', marker='.', markersize=3, linestyle='-', linewidth=2)
axs[1].set_xlabel(r'Wavelength ($\mu$m)')
axs[1].set_xlim(7.5,8.7)
axs[1].annotate('Channel 2', xy=(0.0, 1.02), xycoords='axes fraction', fontsize=12, fontweight='bold', color='k')


plt.show()
